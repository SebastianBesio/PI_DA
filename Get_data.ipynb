# %% [markdown]
# # Obtener Datos desde CoinGecko
#
# Inicialmente probamos hacer el request  con las URL.

# %%
import requests
import pandas as pd
import json

# %%
# url = "https://api.coingecko.com/api/v3/coins/list?include_platform=false"
# r = requests.get(url)
# r.text

# %%
url2 = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=100&page=1&sparkline=false&locale=en"
r = requests.get(url2)
r.text
# Out:
# '[{"id":"bitcoin","symbol":"btc","name":"Bitcoin","image":"https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579","current_price":29329,"market_cap":570767445551,"market_cap_rank":1,"fully_diluted_valuation":615996235839,"total_volume":9835851200,"high_24h":29653,"low_24h":29263,"price_change_24h":-0.7365010507819534,"price_change_percentage_24h":-0.00251,"market_cap_change_24h":-159184383.79785156,"market_cap_change_percentage_24h":-0.02788,"circulating_supply":19458100.0,"total_supply":21000000.0,"max_supply":21000000.0,"ath":69045,"ath_change_percentage":-57.51647,"ath_date":"2021-11-10T14:24:11.849Z","atl":67.81,"atl_change_percentage":43157.76454,"atl_date":"2013-07-06T00:00:00.000Z","roi":null,"last_updated":"2023-08-15T12:43:25.287Z"},{"id":"ethereum","symbol":"eth","name":"Ethereum","image":"https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880","current_price":1839.59,"market_cap":220998199775,"market_cap_rank":2,"fully_diluted_valuation":220998199775,"total_volume":4077285952,"high_24h":1854.61,"low_24h":1836.08,"price_change_24h":-4.03876718063475,"price_change_percentage_24h":-0.21907,"market_cap_change_24h":-674268794.312439,"market_cap_change_percentage_24h":-0.30417,"circulating_supply":120142222.589507,"total_supply":120142222.589507,"max_supply":null,"ath":4878.26,"ath_change_percentage":-62.29363,"ath_date":"2021-11-10T14:24:19.604Z","atl":0.432979,"atl_change_percentage":424727.83758,"atl_date":"2015-10-20T00:00:00.000Z","roi":{"times":82.85810730658314,"currency":"btc","percentage":8285.810730658313},"last_updated":"2023-08-15T12:43:26.527Z"},{"id":"tether","symbol":"usdt","name":"Tether","image":"https://assets.coingecko.com/coins/images/325/large/Tether.png?1668148663","current_price":0.998265,"market_cap":83266125312,"market_cap_rank":3,"fully_diluted_valuation":83266125312,"total_volume":8595880074,"high_24h":1.001,"low_24h":0.995176,"price_change_24h":-0.000425141467068402,"price_change_percentage_24h":-0.04257,"market_cap_change_24h":-3853644.7757110596,"market_cap_change_percentage_24h":-0.00463,"circulating_supply":83410866925.5156,"total_supply":83410866925.5156,"max_supply":null,"ath":1.32,"ath_change_percentage":-24.55081,"ath_date":"2018-07-24T00:00:00.000Z","atl":0.572521,"atl_change_percentage":74.36299,"atl_date":"2015-03-02T00:00:00.000Z","roi":null,"last_updated":"2023-08-15T12:40:01.184Z"},{"id":"binancecoin","symbol":"bnb","name":"BNB","image":"https://assets.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1644979850","current_price":238.77,"market_cap":36735621076,"market_cap_rank":4,"fully_diluted_valuation":47753204634,"total_volume":328037152,"high_24h":241.0,"low_24h":238.42,"price_change_24h":-1.2642970880679343,"price_change_percentage_24h":-0.52672,"market_cap_change_24h":-206404685.3907318,"market_cap_change_percentage_24h":-0.55873,"circulating_supply":153856150.0,"total_supply":153856150.0,"max_supply":200000000.0,"ath":686.31,"ath_change_percentage":-65.21001,"ath_date":"2021-05-10T07:24:17.097Z","atl":0.0398177,"atl_change_percentage":599547.99583,"atl_date":"2017-10-19T00:00:00.000Z","roi":null,"last_updated":"2023-08-15T12:43:27.681Z"},{"id":"ripple","symbol":"xrp","name":"XRP","image":"https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731","current_price":0.625757,"market_cap":33035321058,"market_cap_rank":5,"fully_diluted_valuation":62581967228,"total_volume":820343472,"high_24h":0.635508,"low_24h":0.62504,"price_change_24h":-0.000407513486668343,"price_change_percentage_24h":-0.06508,"market_cap_change_24h":-63105001.420440674,"market_cap_change_percentage_24h":-0.19066,"circulating_supply":52787284454.0,"total_supply":99988519823.0,"max_supply":100000000000.0,"ath":3.4,"ath_change_percentage":-81.57932,"ath_date":"2018-01-07T00:00:00.000Z","atl":0.00268621,"atl_change_percentage":23204.88887,"atl_date":"2014-05-22T00:00:00.000Z","roi":null,"last_updated":"2023-08-15T12:43:27.731Z"},{"id":"us ...

# %%
type(r.text)
# Out:
# str

# %%
json.loads(r.text)
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 29329,
#   'market_cap': 570767445551,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 615996235839,
#   'total_volume': 9835851200,
#   'high_24h': 29653,
#   'low_24h': 29263,
#   'price_change_24h': -0.7365010507819534,
#   'price_change_percentage_24h': -0.00251,
#   'market_cap_change_24h': -159184383.79785156,
#   'market_cap_change_percentage_24h': -0.02788,
#   'circulating_supply': 19458100.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -57.51647,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 43157.76454,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:25.287Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 1839.59,
#   'market_cap': 220998199775,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 220998199775,
#   'total_volume': 4077285952,
#   'high_24h': 1854.61,
#   'low_24h': 1836.08,
#   'price_change_24h': -4.03876718063475,
#   'price_change_percentage_24h': -0.21907,
#   'market_cap_change_24h': -674268794.312439,
#   'market_cap_change_percentage_24h': -0.30417,
#   'circulating_supply': 120142222.589507,
#   'total_supply': 120142222.589507,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -62.29363,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 424727.83758,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 82.85810730658314,
#    'currency': 'btc',
#    'percentage': 8285.810730658313},
#   'last_updated': '2023-08-15T12:43:26.527Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether.png?1668148663',
#   'current_price': 0.998265,
#   'market_cap': 83266125312,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 83266125312,
#   'total_volume': 8595880074,
#   'high_24h': 1.001,
#   'low_24h': 0.995176,
#   'price_change_24h': -0.000425141467068402,
#   'price_change_percentage_24h': -0.04257,
#   'market_cap_change_24h': -3853644.7757110596,
#   'market_cap_change_percentage_24h': -0.00463,
#   'circulating_supply': 83410866925.5156,
#   'total_supply': 83410866925.5156,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.55081,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.36299,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:40:01.184Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1644979850',
#   'current_price': 238.77,
#   'market_cap': 36735621076,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 47753204634,
#   'total_volume': 328037152,
#   'high_24h': 241.0,
#   'low_24h': 238.42,
#   'price_change_24h': -1.2642970880679343,
#   'price_change_percentage_24h': -0.52672,
#   'market_cap_change_24h': -206404685.3907318,
#   'market_cap_change_percentage_24h': -0.55873,
#   'circulating_supply': 153856150.0,
#   'total_supply': 153856150.0,
#   'max_supply': 200000000.0,
#   'ath': 686.31,
#   'ath_change_percentage': -65.21001,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 599547.99583,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.681Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 0.625757,
#   'market_cap': 33035321058,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 62581967228,
#   'total_volume': 820343472,
#   'high_24h': 0.635508,
#   'low_24h': 0.62504,
#   'price_change_24h': -0.000407513486668343,
#   'price_change_percentage_24h': -0.06508,
#   'market_cap_change_24h': -63105001.420440674,
#   'market_cap_change_percentage_24h': -0.19066,
#   'circulating_supply': 52787284454.0,
#   'total_supply': 99988519823.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -81.57932,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 23204.88887,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.731Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 1.0,
#   'market_cap': 25969755200,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 25969577787,
#   'total_volume': 3010038767,
#   'high_24h': 1.002,
#   'low_24h': 0.995914,
#   'price_change_24h': 0.00024213,
#   'price_change_percentage_24h': 0.02422,
#   'market_cap_change_24h': -164682456.32925797,
#   'market_cap_change_percentage_24h': -0.63014,
#   'circulating_supply': 25967359322.3609,
#   'total_supply': 25967181926.0109,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.71928,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.95158,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:21.361Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 1837.64,
#   'market_cap': 14925772041,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 14925772041,
#   'total_volume': 10598381,
#   'high_24h': 1853.33,
#   'low_24h': 1835.73,
#   'price_change_24h': -6.47094060467407,
#   'price_change_percentage_24h': -0.3509,
#   'market_cap_change_24h': -12185675.784816742,
#   'market_cap_change_percentage_24h': -0.08158,
#   'circulating_supply': 8122154.53244262,
#   'total_supply': 8122101.25251175,
#   'max_supply': 8122154.53244262,
#   'ath': 4829.57,
#   'ath_change_percentage': -61.94995,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 280.54841,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:25.701Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.074022,
#   'market_cap': 10411799564,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 10411789937,
#   'total_volume': 404519911,
#   'high_24h': 0.075371,
#   'low_24h': 0.073692,
#   'price_change_24h': -0.000521577279289032,
#   'price_change_percentage_24h': -0.69969,
#   'market_cap_change_24h': -75250530.03225136,
#   'market_cap_change_percentage_24h': -0.71756,
#   'circulating_supply': 140599826383.705,
#   'total_supply': 140599696383.705,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -89.87583,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 85127.83975,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:23.412Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 0.288862,
#   'market_cap': 10121093058,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 12996116904,
#   'total_volume': 117957641,
#   'high_24h': 0.292078,
#   'low_24h': 0.287716,
#   'price_change_24h': -0.000493985022704535,
#   'price_change_percentage_24h': -0.17072,
#   'market_cap_change_24h': -27928747.82666588,
#   'market_cap_change_percentage_24h': -0.27519,
#   'circulating_supply': 35045020830.3234,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -90.6445,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 1400.02469,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.736Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/solana.png?1640133422',
#   'current_price': 24.79,
#   'market_cap': 10069268077,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 13759574361,
#   'total_volume': 425018473,
#   'high_24h': 25.24,
#   'low_24h': 24.36,
#   'price_change_24h': 0.381405,
#   'price_change_percentage_24h': 1.56251,
#   'market_cap_change_24h': 145420166,
#   'market_cap_change_percentage_24h': 1.46536,
#   'circulating_supply': 406100435.634079,
#   'total_supply': 554933000.022804,
#   'max_supply': None,
#   'ath': 259.96,
#   'ath_change_percentage': -90.46235,
#   'ath_date': '2021-11-06T21:54:35.825Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 4850.86909,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:22.184Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.077014,
#   'market_cap': 6888892451,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 6888916413,
#   'total_volume': 177382141,
#   'high_24h': 0.077575,
#   'low_24h': 0.076974,
#   'price_change_24h': -0.000336976039376755,
#   'price_change_percentage_24h': -0.43565,
#   'market_cap_change_24h': -36076429.02697468,
#   'market_cap_change_percentage_24h': -0.52096,
#   'circulating_supply': 89467096272.5275,
#   'total_supply': 89467407475.9461,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -66.77146,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 4166.45831,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 39.533467270591444,
#    'currency': 'usd',
#    'percentage': 3953.346727059144},
#   'last_updated': '2023-08-15T12:43:26.895Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/polkadot.png?1639712644',
#   'current_price': 4.96,
#   'market_cap': 6266712593,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 6667908236,
#   'total_volume': 84182161,
#   'high_24h': 5.04,
#   'low_24h': 4.95,
#   'price_change_24h': -0.023679991457912664,
#   'price_change_percentage_24h': -0.47543,
#   'market_cap_change_24h': -34203974.45476246,
#   'market_cap_change_percentage_24h': -0.54284,
#   'circulating_supply': 1264432853.44409,
#   'total_supply': 1345381986.35965,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -90.98344,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 83.78002,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:25.061Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 0.672089,
#   'market_cap': 6265893052,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 6723444228,
#   'total_volume': 144956820,
#   'high_24h': 0.684453,
#   'low_24h': 0.672038,
#   'price_change_24h': -0.006501830304998513,
#   'price_change_percentage_24h': -0.95814,
#   'market_cap_change_24h': -64438301.25228977,
#   'market_cap_change_percentage_24h': -1.01793,
#   'circulating_supply': 9319469069.28493,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.92,
#   'ath_change_percentage': -76.94502,
#   'ath_date': '2021-12-27T02:08:34.307Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 21286.61302,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 254.54698616900058,
#    'currency': 'usd',
#    'percentage': 25454.698616900056},
#   'last_updated': '2023-08-15T12:43:30.391Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 1.023e-05,
#   'market_cap': 6027321297,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 10227191289,
#   'total_volume': 275826693,
#   'high_24h': 1.051e-05,
#   'low_24h': 1.005e-05,
#   'price_change_24h': -2.10132245545e-07,
#   'price_change_percentage_24h': -2.01274,
#   'market_cap_change_24h': -131020262.09236145,
#   'market_cap_change_percentage_24h': -2.12753,
#   'circulating_supply': 589334747038819.1,
#   'total_supply': 999986377821837.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -88.12874,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 18145698.66069,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.560Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 81.65,
#   'market_cap': 6003813271,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 6857373444,
#   'total_volume': 319962777,
#   'high_24h': 82.95,
#   'low_24h': 81.45,
#   'price_change_24h': -0.2111812449949042,
#   'price_change_percentage_24h': -0.25798,
#   'market_cap_change_24h': -20839136.914196968,
#   'market_cap_change_percentage_24h': -0.3459,
#   'circulating_supply': 73544239.4834713,
#   'total_supply': 84000000.0,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -80.09907,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 7006.76535,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:31.524Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://assets.coingecko.com/coins/images/17980/large/ton_symbol.png?1670498136',
#   'current_price': 1.48,
#   'market_cap': 5093679036,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 7542838240,
#   'total_volume': 36318892,
#   'high_24h': 1.49,
#   'low_24h': 1.41,
#   'price_change_24h': 0.063125,
#   'price_change_percentage_24h': 4.44969,
#   'market_cap_change_24h': 211613620,
#   'market_cap_change_percentage_24h': 4.33451,
#   'circulating_supply': 3438551897.57464,
#   'total_supply': 5091887525.74186,
#   'max_supply': None,
#   'ath': 5.29,
#   'ath_change_percentage': -71.80603,
#   'ath_date': '2021-11-12T06:50:02.476Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 187.21396,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:29.874Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 29355,
#   'market_cap': 4760729787,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 4760729787,
#   'total_volume': 56751849,
#   'high_24h': 29620,
#   'low_24h': 29291,
#   'price_change_24h': 30.82,
#   'price_change_percentage_24h': 0.10511,
#   'market_cap_change_24h': 3594162,
#   'market_cap_change_percentage_24h': 0.07555,
#   'circulating_supply': 162205.42767567,
#   'total_supply': 162205.42767567,
#   'max_supply': 162205.42767567,
#   'ath': 70643,
#   'ath_change_percentage': -58.4533,
#   'ath_date': '2021-11-10T14:40:19.650Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 834.95964,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:31.537Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uni.jpg?1687143398',
#   'current_price': 6.24,
#   'market_cap': 4702839198,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 6239118024,
#   'total_volume': 79535937,
#   'high_24h': 6.35,
#   'low_24h': 6.17,
#   'price_change_24h': 0.050879,
#   'price_change_percentage_24h': 0.82228,
#   'market_cap_change_24h': 36007134,
#   'market_cap_change_percentage_24h': 0.77155,
#   'circulating_supply': 753766667.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -86.11078,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 505.60522,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:25.748Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 234.76,
#   'market_cap': 4572370710,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 4929918978,
#   'total_volume': 201432794,
#   'high_24h': 234.77,
#   'low_24h': 227.51,
#   'price_change_24h': 6.7,
#   'price_change_percentage_24h': 2.9379,
#   'market_cap_change_24h': 126575178,
#   'market_cap_change_percentage_24h': 2.84708,
#   'circulating_supply': 19476949.8966508,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -93.79902,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 205.13898,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.944Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1670992574',
#   'current_price': 12.29,
#   'market_cap': 4224834083,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 8846896144,
#   'total_volume': 92304776,
#   'high_24h': 12.43,
#   'low_24h': 12.25,
#   'price_change_24h': 0.00719087,
#   'price_change_percentage_24h': 0.05855,
#   'market_cap_change_24h': -2169238.2878904343,
#   'market_cap_change_percentage_24h': -0.05132,
#   'circulating_supply': 343835904.711615,
#   'total_supply': 430554700.06121,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -91.5228,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 338.71378,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.556Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/Badge_Dai.png?1687143508',
#   'current_price': 0.999744,
#   'market_cap': 3923697110,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 3923697110,
#   'total_volume': 88157774,
#   'high_24h': 1.002,
#   'low_24h': 0.998087,
#   'price_change_24h': 0.00049083,
#   'price_change_percentage_24h': 0.04912,
#   'market_cap_change_24h': -44586820.80926466,
#   'market_cap_change_percentage_24h': -1.12358,
#   'circulating_supply': 3924700036.94898,
#   'total_supply': 3924700036.94898,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.98183,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.35487,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:40:00.232Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 7.29,
#   'market_cap': 3922218010,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 7289013603,
#   'total_volume': 238452230,
#   'high_24h': 7.6,
#   'low_24h': 7.27,
#   'price_change_24h': -0.21524160064683073,
#   'price_change_percentage_24h': -2.86896,
#   'market_cap_change_24h': -123939191.65687561,
#   'market_cap_change_percentage_24h': -3.06313,
#   'circulating_supply': 538099971.2305644,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -86.16777,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 4818.98975,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:24.503Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://assets.coingecko.com/coins/images/8418/large/leo-token.png?1558326215',
#   'current_price': 3.97,
#   'market_cap': 3689705979,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 3910457471,
#   'total_volume': 1326239,
#   'high_24h': 4.0,
#   'low_24h': 3.94,
#   'price_change_24h': 0.01042696,
#   'price_change_percentage_24h': 0.26339,
#   'market_cap_change_24h': 8778171,
#   'market_cap_change_percentage_24h': 0.23848,
#   'circulating_supply': 929621179.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 8.14,
#   'ath_change_percentage': -51.21137,
#   'ath_date': '2022-02-08T17:40:10.285Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 396.22764,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:26.688Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.134629,
#   'market_cap': 3684080849,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 6729322508,
#   'total_volume': 71685871,
#   'high_24h': 0.137587,
#   'low_24h': 0.134071,
#   'price_change_24h': -0.001758286374724916,
#   'price_change_percentage_24h': -1.28918,
#   'market_cap_change_24h': -53408061.81282663,
#   'market_cap_change_percentage_24h': -1.42898,
#   'circulating_supply': 27374319860.8204,
#   'total_supply': 50001787244.4735,
#   'max_supply': 50001787244.4735,
#   'ath': 0.875563,
#   'ath_change_percentage': -84.63272,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 28159.5188,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.796Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 0.999569,
#   'market_cap': 3346048433,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 3346048433,
#   'total_volume': 1793970210,
#   'high_24h': 1.004,
#   'low_24h': 0.994065,
#   'price_change_24h': 0.00041086,
#   'price_change_percentage_24h': 0.04112,
#   'market_cap_change_24h': -15255644.625291824,
#   'market_cap_change_percentage_24h': -0.45386,
#   'circulating_supply': 3347271842.98,
#   'total_supply': 3347271842.98,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.4013,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 10.91948,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:31.413Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 157.75,
#   'market_cap': 2863175453,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': None,
#   'total_volume': 73696180,
#   'high_24h': 159.76,
#   'low_24h': 157.69,
#   'price_change_24h': -1.0447756667056183,
#   'price_change_percentage_24h': -0.65792,
#   'market_cap_change_24h': -21275644.494925976,
#   'market_cap_change_percentage_24h': -0.7376,
#   'circulating_supply': 18147820.3764146,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -70.90844,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 72882.40772,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.178Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1642471050',
#   'current_price': 46.41,
#   'market_cap': 2781400740,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 13907003700,
#   'total_volume': 3419177,
#   'high_24h': 47.19,
#   'low_24h': 46.34,
#   'price_change_24h': -0.3043497586065058,
#   'price_change_percentage_24h': -0.65145,
#   'market_cap_change_24h': -21859954.516953945,
#   'market_cap_change_percentage_24h': -0.7798,
#   'circulating_supply': 60000000.0,
#   'total_supply': 235957685.3,
#   'max_supply': 300000000.0,
#   'ath': 58.66,
#   'ath_change_percentage': -21.01921,
#   'ath_date': '2023-02-18T01:21:37.582Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 7879.40234,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:29.843Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'image': 'https://assets.coingecko.com/coins/images/3449/large/tusd.png?1618395665',
#   'current_price': 0.998068,
#   'market_cap': 2776864177,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 2776864177,
#   'total_volume': 311281341,
#   'high_24h': 1.001,
#   'low_24h': 0.995824,
#   'price_change_24h': -3.1482210587352e-05,
#   'price_change_percentage_24h': -0.00315,
#   'market_cap_change_24h': 966580,
#   'market_cap_change_percentage_24h': 0.03482,
#   'circulating_supply': 2782074781.45,
#   'total_supply': 2782074781.45,
#   'max_supply': None,
#   'ath': 1.62,
#   'ath_change_percentage': -38.31637,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 0.88355,
#   'atl_change_percentage': 12.9939,
#   'atl_date': '2020-03-12T10:47:51.380Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:29.391Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos Hub',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 8.47,
#   'market_cap': 2481898194,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': None,
#   'total_volume': 71646385,
#   'high_24h': 8.56,
#   'low_24h': 8.43,
#   'price_change_24h': 0.03385346,
#   'price_change_percentage_24h': 0.40127,
#   'market_cap_change_24h': 11531611,
#   'market_cap_change_percentage_24h': 0.4668,
#   'circulating_supply': 292586163.827428,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 44.45,
#   'ath_change_percentage': -80.91528,
#   'ath_date': '2022-01-17T00:34:41.497Z',
#   'atl': 1.16,
#   'atl_change_percentage': 631.23731,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 83.70441894647404,
#    'currency': 'usd',
#    'percentage': 8370.441894647403},
#   'last_updated': '2023-08-15T12:43:21.872Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 17.29,
#   'market_cap': 2463825781,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 3643083805,
#   'total_volume': 58298352,
#   'high_24h': 17.6,
#   'low_24h': 17.26,
#   'price_change_24h': -0.18903405944468687,
#   'price_change_percentage_24h': -1.08163,
#   'market_cap_change_24h': -28029241.661723137,
#   'market_cap_change_percentage_24h': -1.12483,
#   'circulating_supply': 142496884.479804,
#   'total_supply': 210700000.0,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -89.65185,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 2711.24904,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 37.41733409974407,
#    'currency': 'usd',
#    'percentage': 3741.7334099744066},
#   'last_updated': '2023-08-15T12:43:29.025Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://assets.coingecko.com/coins/images/3688/large/hbar.png?1637045634',
#   'current_price': 0.071813,
#   'market_cap': 2369028555,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 3593707293,
#   'total_volume': 341934309,
#   'high_24h': 0.075249,
#   'low_24h': 0.064278,
#   'price_change_24h': 0.00702954,
#   'price_change_percentage_24h': 10.85077,
#   'market_cap_change_24h': 225985126,
#   'market_cap_change_percentage_24h': 10.54506,
#   'circulating_supply': 32960788984.8793,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -87.37342,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 628.86463,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:28.688Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 4.03,
#   'market_cap': 1778156097,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 1889562001,
#   'total_volume': 16588290,
#   'high_24h': 4.12,
#   'low_24h': 4.02,
#   'price_change_24h': -0.05326197083748063,
#   'price_change_percentage_24h': -1.305,
#   'market_cap_change_24h': -23690181.631046534,
#   'market_cap_change_percentage_24h': -1.31477,
#   'circulating_supply': 441549533.020737,
#   'total_supply': 503892780.891811,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -99.42515,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 3.4,
#   'atl_change_percentage': 18.49481,
#   'atl_date': '2022-12-19T22:45:01.729Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.914Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 4.02,
#   'market_cap': 1777876085,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 7882118474,
#   'total_volume': 64377641,
#   'high_24h': 4.12,
#   'low_24h': 4.01,
#   'price_change_24h': -0.06296835407730583,
#   'price_change_percentage_24h': -1.54277,
#   'market_cap_change_24h': -27155095.73915577,
#   'market_cap_change_percentage_24h': -1.50441,
#   'circulating_supply': 442452425.0,
#   'total_supply': 1961589147.0,
#   'max_supply': 1961589147.0,
#   'ath': 236.84,
#   'ath_change_percentage': -98.30329,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 2.64,
#   'atl_change_percentage': 52.15959,
#   'atl_date': '2022-12-16T22:45:28.552Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:23.104Z'},
#  {'id': 'lido-dao',
#   'symbol': 'ldo',
#   'name': 'Lido DAO',
#   'image': 'https://assets.coingecko.com/coins/images/13573/large/Lido_DAO.png?1609873644',
#   'current_price': 1.81,
#   'market_cap': 1594162342,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 1813940467,
#   'total_volume': 43134866,
#   'high_24h': 1.85,
#   'low_24h': 1.81,
#   'price_change_24h': -0.012880684169476632,
#   'price_change_percentage_24h': -0.70494,
#   'market_cap_change_24h': -13246584.054808378,
#   'market_cap_change_percentage_24h': -0.8241,
#   'circulating_supply': 878839394.66521,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 7.3,
#   'ath_change_percentage': -75.15661,
#   'ath_date': '2021-08-20T08:35:20.158Z',
#   'atl': 0.40615,
#   'atl_change_percentage': 346.70249,
#   'atl_date': '2022-06-18T20:55:12.035Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.790Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'image': 'https://assets.coingecko.com/coins/images/26455/large/aptos_round.png?1666839629',
#   'current_price': 6.93,
#   'market_cap': 1561998410,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 7275733947,
#   'total_volume': 56053907,
#   'high_24h': 7.13,
#   'low_24h': 6.91,
#   'price_change_24h': -0.12102945272780374,
#   'price_change_percentage_24h': -1.71652,
#   'market_cap_change_24h': -26728604.82013035,
#   'market_cap_change_percentage_24h': -1.68239,
#   'circulating_supply': 225416378.639718,
#   'total_supply': 1049981605.726,
#   'max_supply': None,
#   'ath': 19.92,
#   'ath_change_percentage': -65.20408,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 3.08,
#   'atl_change_percentage': 125.06316,
#   'atl_date': '2022-12-29T21:35:14.796Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:28.380Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cro_token_logo.png?1669699773',
#   'current_price': 0.056536,
#   'market_cap': 1481710647,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 1695632804,
#   'total_volume': 3902568,
#   'high_24h': 0.057041,
#   'low_24h': 0.056486,
#   'price_change_24h': -0.000415108191703387,
#   'price_change_percentage_24h': -0.72889,
#   'market_cap_change_24h': -11636147.32960701,
#   'market_cap_change_percentage_24h': -0.7792,
#   'circulating_supply': 26215180144.4149,
#   'total_supply': 30000000000.0,
#   'max_supply': None,
#   'ath': 0.965407,
#   'ath_change_percentage': -94.14448,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 366.4316,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:24.267Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://assets.coingecko.com/coins/images/30980/large/token-logo.png?1689320029',
#   'current_price': 0.45737,
#   'market_cap': 1479368708,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 2844743147,
#   'total_volume': 7840197,
#   'high_24h': 0.459984,
#   'low_24h': 0.456675,
#   'price_change_24h': -0.001865880378092155,
#   'price_change_percentage_24h': -0.4063,
#   'market_cap_change_24h': -6431913.986861706,
#   'market_cap_change_percentage_24h': -0.43289,
#   'circulating_supply': 3234268324.76314,
#   'total_supply': 6219316794.99,
#   'max_supply': 6219316794.99,
#   'ath': 0.600075,
#   'ath_change_percentage': -23.88168,
#   'ath_date': '2023-07-20T22:39:30.228Z',
#   'atl': 0.45061,
#   'atl_change_percentage': 1.36629,
#   'atl_date': '2023-08-08T23:34:42.573Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:24.730Z'},
#  {'id': 'quant-network',
#   'symbol': 'qnt',
#   'name': 'Quant',
#   'image': 'https://assets.coingecko.com/coins/images/3370/large/5ZOu7brX_400x400.jpg?1612437252',
#   'current_price': 100.65,
#   'market_cap': 1463684300,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 1470559511,
#   'total_volume': 14929827,
#   'high_24h': 101.54,
#   'low_24h': 100.14,
#   'price_change_24h': -0.6988689305199784,
#   'price_change_percentage_24h': -0.68958,
#   'market_cap_change_24h': -11673153.730322838,
#   'market_cap_change_percentage_24h': -0.79121,
#   'circulating_supply': 14544176.164091088,
#   'total_supply': 14612493.0,
#   'max_supply': 14612493.0,
#   'ath': 427.42,
#   'ath_change_percentage': -76.452,
#   'ath_date': '2021-09-11T09:15:00.668Z',
#   'atl': 0.215773,
#   'atl_change_percentage': 46545.91434,
#   'atl_date': '2018-08-23T00:00:00.000Z',
#   'roi': {'times': 22.526151325317997,
#    'currency': 'eth',
#    'percentage': 2252.6151325317996},
#   'last_updated': '2023-08-15T12:43:25.097Z'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'image': 'https://assets.coingecko.com/coins/images/16547/large/photo_2023-03-29_21.47.00.jpeg?1680097630',
#   'current_price': 1.14,
#   'market_cap': 1452838904,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 11394814935,
#   'total_volume': 97130002,
#   'high_24h': 1.15,
#   'low_24h': 1.13,
#   'price_change_24h': 0.00179455,
#   'price_change_percentage_24h': 0.1577,
#   'market_cap_change_24h': 1075966,
#   'market_cap_change_percentage_24h': 0.07411,
#   'circulating_supply': 1275000000.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 8.67,
#   'ath_change_percentage': -86.879,
#   'ath_date': '2023-03-23T13:10:03.106Z',
#   'atl': 0.912886,
#   'atl_change_percentage': 24.66167,
#   'atl_date': '2023-06-15T07:25:14.752Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:28.622Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VET_Token_Icon.png?1680067517',
#   'current_price': 0.01829526,
#   'market_cap': 1330351217,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 1586454313,
#   'total_volume': 33019463,
#   'high_24h': 0.01873866,
#   'low_24h': 0.01827431,
#   'price_change_24h': -8.14537198799e-06,
#   'price_change_percentage_24h': -0.0445,
#   'market_cap_change_24h': -1769968.9392726421,
#   'market_cap_change_percentage_24h': -0.13287,
#   'circulating_supply': 72714516834.0,
#   'total_supply': 85985041177.0,
#   'max_supply': 86712634466.0,
#   'ath': 0.280991,
#   'ath_change_percentage': -93.48986,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 854.18105,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 2.4808543492436805,
#    'currency': 'eth',
#    'percentage': 248.08543492436803},
#   'last_updated': '2023-08-15T12:43:28.534Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/10365/large/near.jpg?1683515160',
#   'current_price': 1.33,
#   'market_cap': 1251975260,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 1329524400,
#   'total_volume': 40272846,
#   'high_24h': 1.35,
#   'low_24h': 1.32,
#   'price_change_24h': -0.005582062291897173,
#   'price_change_percentage_24h': -0.41803,
#   'market_cap_change_24h': -7213628.5976986885,
#   'market_cap_change_percentage_24h': -0.57288,
#   'circulating_supply': 941671517.686093,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -93.49388,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 152.43405,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:24.333Z'},
#  {'id': 'maker',
#   'symbol': 'mkr',
#   'name': 'Maker',
#   'image': 'https://assets.coingecko.com/coins/images/1364/large/Mark_Maker.png?1585191826',
#   'current_price': 1230.04,
#   'market_cap': 1108805608,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 1237075196,
#   'total_volume': 103552408,
#   'high_24h': 1271.11,
#   'low_24h': 1227.14,
#   'price_change_24h': -30.819006281690235,
#   'price_change_percentage_24h': -2.44429,
#   'market_cap_change_24h': -29371856.37425685,
#   'market_cap_change_percentage_24h': -2.5806,
#   'circulating_supply': 901310.9472893132,
#   'total_supply': 977631.036950888,
#   'max_supply': 1005577.0,
#   'ath': 6292.31,
#   'ath_change_percentage': -80.43398,
#   'ath_date': '2021-05-03T21:54:29.333Z',
#   'atl': 168.36,
#   'atl_change_percentage': 631.27424,
#   'atl_date': '2020-03-16T20:52:36.527Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.845Z'},
#  {'id': 'optimism',
#   'symbol': 'op',
#   'name': 'Optimism',
#   'image': 'https://assets.coingecko.com/coins/images/25244/large/Optimism.png?1660904599',
#   'current_price': 1.51,
#   'market_cap': 1083900646,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 6495409479,
#   'total_volume': 68725802,
#   'high_24h': 1.57,
#   'low_24h': 1.5,
#   'price_change_24h': -0.046590340474999214,
#   'price_change_percentage_24h': -2.98886,
#   'market_cap_change_24h': -32615606.048403263,
#   'market_cap_change_percentage_24h': -2.92119,
#   'circulating_supply': 716708907.0,
#   'total_supply': 4294967296.0,
#   'max_supply': 4294967296.0,
#   'ath': 3.22,
#   'ath_change_percentage': -53.04292,
#   'ath_date': '2023-02-24T20:20:00.509Z',
#   'atl': 0.402159,
#   'atl_change_percentage': 276.34728,
#   'atl_date': '2022-06-18T20:54:52.178Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.903Z'},
#  {'id': 'rocket-pool-eth',
#   'symbol': 'reth',
#   'name': 'Rocket Pool ETH',
#   'image': 'https://assets.coingecko.com/coins/images/20764/large/reth.png?1637652366',
#   'current_price': 1998.76,
#   'market_cap': 995178904,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 995178904,
#   'total_volume': 8474928,
#   'high_24h': 2014.13,
#   'low_24h': 1996.22,
#   'price_change_24h': -4.232326746433273,
#   'price_change_percentage_24h': -0.2113,
#   'market_cap_change_24h': -2556755.5478622913,
#   'market_cap_change_percentage_24h': -0.25626,
#   'circulating_supply': 497845.713528374,
#   'total_supply': 497845.713528374,
#   'max_supply': None,
#   'ath': 4814.31,
#   'ath_change_percentage': -58.50265,
#   'ath_date': '2021-12-01T08:03:50.749Z',
#   'atl': 887.26,
#   'atl_change_percentage': 125.16548,
#   'atl_date': '2022-06-18T20:55:45.957Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.225Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 0.107125,
#   'market_cap': 974966441,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 1068062741,
#   'total_volume': 48171666,
#   'high_24h': 0.110345,
#   'low_24h': 0.106465,
#   'price_change_24h': -0.000629714044931187,
#   'price_change_percentage_24h': -0.5844,
#   'market_cap_change_24h': -8376056.077914,
#   'market_cap_change_percentage_24h': -0.85179,
#   'circulating_supply': 9128363004.67671,
#   'total_supply': 10000000000.0,
#   'max_supply': None,
#   'ath': 2.84,
#   'ath_change_percentage': -96.22992,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.052051,
#   'atl_change_percentage': 105.81153,
#   'atl_date': '2022-11-22T10:05:03.503Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:21.381Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 65.17,
#   'market_cap': 945921034,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 1042778358,
#   'total_volume': 59006565,
#   'high_24h': 66.42,
#   'low_24h': 65.07,
#   'price_change_24h': -0.7526145017892958,
#   'price_change_percentage_24h': -1.14173,
#   'market_cap_change_24h': -11945346.993058681,
#   'market_cap_change_percentage_24h': -1.24708,
#   'circulating_supply': 14513857.545398107,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -90.1523,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 150.39728,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:24.591Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 0.112527,
#   'market_cap': 879521445,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 1125722096,
#   'total_volume': 31439632,
#   'high_24h': 0.117223,
#   'low_24h': 0.112505,
#   'price_change_24h': -0.002956520510319749,
#   'price_change_percentage_24h': -2.56013,
#   'market_cap_change_24h': -23375947.002483368,
#   'market_cap_change_percentage_24h': -2.58899,
#   'circulating_supply': 7812953559.66348,
#   'total_supply': 7812953569.16148,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -96.83869,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.098399,
#   'atl_change_percentage': 14.41117,
#   'atl_date': '2023-06-10T04:31:46.997Z',
#   'roi': {'times': -0.9531139423651065,
#    'currency': 'usd',
#    'percentage': -95.31139423651065},
#   'last_updated': '2023-08-15T12:43:30.156Z'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'image': 'https://assets.coingecko.com/coins/images/2912/large/xdc-icon.png?1633700890',
#   'current_price': 0.060151,
#   'market_cap': 833710784,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 2277747723,
#   'total_volume': 12893211,
#   'high_24h': 0.063146,
#   'low_24h': 0.059177,
#   'price_change_24h': -0.001694352660531785,
#   'price_change_percentage_24h': -2.73965,
#   'market_cap_change_24h': -23923187.940859318,
#   'market_cap_change_percentage_24h': -2.78944,
#   'circulating_supply': 13856332571.85,
#   'total_supply': 37856329275.15,
#   'max_supply': None,
#   'ath': 0.192754,
#   'ath_change_percentage': -68.78926,
#   'ath_date': '2021-08-21T04:39:48.324Z',
#   'atl': 0.00039532,
#   'atl_change_percentage': 15118.12237,
#   'atl_date': '2019-07-22T00:00:00.000Z',
#   'roi': {'times': 3.3481596548508046,
#    'currency': 'eth',
#    'percentage': 334.8159654850804},
#   'last_updated': '2023-08-15T12:43:24.255Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://assets.coingecko.com/coins/images/27045/large/wbt_token.png?1667923752',
#   'current_price': 5.65,
#   'market_cap': 813573559,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 2258068082,
#   'total_volume': 8321119,
#   'high_24h': 5.66,
#   'low_24h': 5.53,
#   'price_change_24h': 0.114426,
#   'price_change_percentage_24h': 2.06849,
#   'market_cap_change_24h': 16334555,
#   'market_cap_change_percentage_24h': 2.04889,
#   'circulating_supply': 144118517.10815412,
#   'total_supply': 368808535.0,
#   'max_supply': 400000000.0,
#   'ath': 14.64,
#   'ath_change_percentage': -61.44128,
#   'ath_date': '2022-10-28T12:32:18.119Z',
#   'atl': 3.06,
#   'atl_change_percentage': 84.43179,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:14.291Z'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Frax',
#   'image': 'https://assets.coingecko.com/coins/images/13422/large/FRAX_icon.png?1679886922',
#   'current_price': 0.997927,
#   'market_cap': 811175962,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 811175962,
#   'total_volume': 15805416,
#   'high_24h': 1.002,
#   'low_24h': 0.996147,
#   'price_change_24h': -0.001729733951409185,
#   'price_change_percentage_24h': -0.17303,
#   'market_cap_change_24h': -1175696.11623919,
#   'market_cap_change_percentage_24h': -0.14473,
#   'circulating_supply': 812641409.408784,
#   'total_supply': 812641409.408784,
#   'max_supply': None,
#   'ath': 1.14,
#   'ath_change_percentage': -12.49907,
#   'ath_date': '2021-02-07T12:55:35.766Z',
#   'atl': 0.874536,
#   'atl_change_percentage': 14.10679,
#   'atl_date': '2023-03-11T07:50:39.316Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:28.545Z'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'image': 'https://assets.coingecko.com/coins/images/2069/large/Stacks_logo_full.png?1604112510',
#   'current_price': 0.576546,
#   'market_cap': 806712576,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 1048466047,
#   'total_volume': 5778587,
#   'high_24h': 0.590317,
#   'low_24h': 0.575775,
#   'price_change_24h': -0.004201477291988387,
#   'price_change_percentage_24h': -0.72346,
#   'market_cap_change_24h': -6780837.791462541,
#   'market_cap_change_percentage_24h': -0.83355,
#   'circulating_supply': 1398808734.156,
#   'total_supply': 1818000000.0,
#   'max_supply': 1818000000.0,
#   'ath': 3.39,
#   'ath_change_percentage': -82.98596,
#   'ath_date': '2021-12-01T01:32:34.725Z',
#   'atl': 0.04559639,
#   'atl_change_percentage': 1164.82356,
#   'atl_date': '2020-03-13T02:29:26.415Z',
#   'roi': {'times': 3.804547450300129,
#    'currency': 'usd',
#    'percentage': 380.45474503001293},
#   'last_updated': '2023-08-15T12:43:28.338Z'},
#  {'id': 'the-sandbox',
#   'symbol': 'sand',
#   'name': 'The Sandbox',
#   'image': 'https://assets.coingecko.com/coins/images/12129/large/sandbox_logo.jpg?1597397942',
#   'current_price': 0.388667,
#   'market_cap': 799248189,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 1165123363,
#   'total_volume': 87334827,
#   'high_24h': 0.397327,
#   'low_24h': 0.388392,
#   'price_change_24h': -0.005308469496956681,
#   'price_change_percentage_24h': -1.34741,
#   'market_cap_change_24h': -12152176.445913792,
#   'market_cap_change_percentage_24h': -1.49768,
#   'circulating_supply': 2057931926.2233226,
#   'total_supply': 3000000000.0,
#   'max_supply': 3000000000.0,
#   'ath': 8.4,
#   'ath_change_percentage': -95.37494,
#   'ath_date': '2021-11-25T06:04:40.957Z',
#   'atl': 0.02897764,
#   'atl_change_percentage': 1240.19575,
#   'atl_date': '2020-11-04T15:59:14.441Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.877Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1547034481',
#   'current_price': 0.710253,
#   'market_cap': 793039607,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': None,
#   'total_volume': 66489681,
#   'high_24h': 0.723792,
#   'low_24h': 0.707759,
#   'price_change_24h': -0.006684027670088355,
#   'price_change_percentage_24h': -0.9323,
#   'market_cap_change_24h': -8174753.53619504,
#   'market_cap_change_percentage_24h': -1.0203,
#   'circulating_supply': 1116681045.3612,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 22.71,
#   'ath_change_percentage': -96.87315,
#   'ath_date': '2018-04-29T07:50:33.540Z',
#   'atl': 0.5024,
#   'atl_change_percentage': 41.35102,
#   'atl_date': '2017-10-23T00:00:00.000Z',
#   'roi': {'times': -0.2825723430643768,
#    'currency': 'usd',
#    'percentage': -28.257234306437677},
#   'last_updated': '2023-08-15T12:43:23.122Z'},
#  {'id': 'havven',
#   'symbol': 'snx',
#   'name': 'Synthetix Network',
#   'image': 'https://assets.coingecko.com/coins/images/3406/large/SNX.png?1598631139',
#   'current_price': 2.46,
#   'market_cap': 791993209,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 793774808,
# ...
#   'fully_diluted_valuation': 688362177,
#   'total_volume': 49744261,
#   'high_24h': 7.01,
#   'low_24h': 6.7,
#   'price_change_24h': 0.141662,
#   'price_change_percentage_24h': 2.09354,
#   'market_cap_change_24h': 8651776,
#   'market_cap_change_percentage_24h': 1.75058,
#   'circulating_supply': 72821350.6337376,
#   'total_supply': 99681752.7128909,
#   'max_supply': 99681752.7128909,
#   'ath': 42.8,
#   'ath_change_percentage': -83.85867,
#   'ath_date': '2022-01-12T15:22:27.465Z',
#   'atl': 1.5,
#   'atl_change_percentage': 359.59534,
#   'atl_date': '2021-06-25T16:50:51.447Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:27.756Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/klaytn.png?1660288824',
#   'current_price': 0.155939,
#   'market_cap': 498116179,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': None,
#   'total_volume': 5793598,
#   'high_24h': 0.158793,
#   'low_24h': 0.155882,
#   'price_change_24h': -0.001519667336829567,
#   'price_change_percentage_24h': -0.96512,
#   'market_cap_change_24h': -4474109.939489186,
#   'market_cap_change_percentage_24h': -0.89021,
#   'circulating_supply': 3195347341.0609,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -96.40646,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 157.9778,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:29.392Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth.png?1687143191',
#   'current_price': 36.92,
#   'market_cap': 497607629,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 497607629,
#   'total_volume': 4932.94,
#   'high_24h': 37.2,
#   'low_24h': 36.92,
#   'price_change_24h': -0.12760087995321356,
#   'price_change_percentage_24h': -0.34443,
#   'market_cap_change_24h': -9979104.873607099,
#   'market_cap_change_percentage_24h': -1.96599,
#   'circulating_supply': 13478085.818655,
#   'total_supply': 13478085.818655,
#   'max_supply': None,
#   'ath': 97.75,
#   'ath_change_percentage': -62.23065,
#   'ath_date': '2021-11-21T12:39:57.508Z',
#   'atl': 1.89,
#   'atl_change_percentage': 1857.27016,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:00:03.867Z'},
#  {'id': 'curve-dao-token',
#   'symbol': 'crv',
#   'name': 'Curve DAO',
#   'image': 'https://assets.coingecko.com/coins/images/12124/large/Curve.png?1597369484',
#   'current_price': 0.577803,
#   'market_cap': 495601253,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 1908834135,
#   'total_volume': 46004340,
#   'high_24h': 0.58571,
#   'low_24h': 0.571555,
#   'price_change_24h': -0.001580971538704401,
#   'price_change_percentage_24h': -0.27287,
#   'market_cap_change_24h': -11088168.112055957,
#   'market_cap_change_percentage_24h': -2.18836,
#   'circulating_supply': 857584180.0,
#   'total_supply': 1996598128.81827,
#   'max_supply': 3303030299.0,
#   'ath': 15.37,
#   'ath_change_percentage': -96.24046,
#   'ath_date': '2020-08-14T00:00:00.000Z',
#   'atl': 0.331577,
#   'atl_change_percentage': 74.29441,
#   'atl_date': '2020-11-05T13:09:50.181Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:31.146Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://assets.coingecko.com/coins/images/9519/large/paxgold.png?1687143101',
#   'current_price': 1899.98,
#   'market_cap': 471545929,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 471545929,
#   'total_volume': 7651786,
#   'high_24h': 1906.83,
#   'low_24h': 1897.22,
#   'price_change_24h': -2.34483220254333,
#   'price_change_percentage_24h': -0.12326,
#   'market_cap_change_24h': -982413.151474297,
#   'market_cap_change_percentage_24h': -0.20791,
#   'circulating_supply': 248343.361,
#   'total_supply': 248343.361,
#   'max_supply': None,
#   'ath': 2241.37,
#   'ath_change_percentage': -15.23472,
#   'ath_date': '2021-05-17T19:02:29.657Z',
#   'atl': 1399.64,
#   'atl_change_percentage': 35.74211,
#   'atl_date': '2019-11-18T03:09:35.959Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:22.073Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://assets.coingecko.com/coins/images/10481/large/Tether_Gold.png?1668148656',
#   'current_price': 1901.61,
#   'market_cap': 468844014,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 468844014,
#   'total_volume': 3769748,
#   'high_24h': 1914.09,
#   'low_24h': 1901.91,
#   'price_change_24h': -7.039005944818655,
#   'price_change_percentage_24h': -0.36879,
#   'market_cap_change_24h': -1399088.5363642573,
#   'market_cap_change_percentage_24h': -0.29752,
#   'circulating_supply': 246524.33,
#   'total_supply': 246524.33,
#   'max_supply': None,
#   'ath': 2169.74,
#   'ath_change_percentage': -12.33943,
#   'ath_date': '2023-03-15T20:36:21.941Z',
#   'atl': 1447.84,
#   'atl_change_percentage': 31.36847,
#   'atl_date': '2020-03-19T13:45:41.821Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:26.704Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 0.167062,
#   'market_cap': 464462167,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 464462167,
#   'total_volume': 4467779,
#   'high_24h': 0.169993,
#   'low_24h': 0.166786,
#   'price_change_24h': -0.001659898012575711,
#   'price_change_percentage_24h': -0.98381,
#   'market_cap_change_24h': -4602981.680518746,
#   'market_cap_change_percentage_24h': -0.98131,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -96.81671,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 104.66609,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 3.250735972279074,
#    'currency': 'btc',
#    'percentage': 325.0735972279074},
#   'last_updated': '2023-08-15T12:43:25.100Z'},
#  {'id': 'thorchain',
#   'symbol': 'rune',
#   'name': 'THORChain',
#   'image': 'https://assets.coingecko.com/coins/images/6595/large/Rune200x200.png?1671179394',
#   'current_price': 1.55,
#   'market_cap': 463272187,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 770321454,
#   'total_volume': 168094630,
#   'high_24h': 1.59,
#   'low_24h': 1.36,
#   'price_change_24h': 0.181736,
#   'price_change_percentage_24h': 13.3166,
#   'market_cap_change_24h': 52414904,
#   'market_cap_change_percentage_24h': 12.75745,
#   'circulating_supply': 300700561.0,
#   'total_supply': 500000000.0,
#   'max_supply': 500000000.0,
#   'ath': 20.87,
#   'ath_change_percentage': -92.61705,
#   'ath_date': '2021-05-19T00:30:09.436Z',
#   'atl': 0.00851264,
#   'atl_change_percentage': 17998.30046,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 39.696509011035054,
#    'currency': 'usd',
#    'percentage': 3969.6509011035055},
#   'last_updated': '2023-08-15T12:43:22.569Z'},
#  {'id': 'frax-ether',
#   'symbol': 'frxeth',
#   'name': 'Frax Ether',
#   'image': 'https://assets.coingecko.com/coins/images/28284/large/frxETH_icon.png?1679886981',
#   'current_price': 1836.05,
#   'market_cap': 456113066,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 456113066,
#   'total_volume': 1803582,
#   'high_24h': 1851.07,
#   'low_24h': 1832.69,
#   'price_change_24h': -4.5558272019413835,
#   'price_change_percentage_24h': -0.24752,
#   'market_cap_change_24h': -724022.5230167508,
#   'market_cap_change_percentage_24h': -0.15849,
#   'circulating_supply': 248388.734467301,
#   'total_supply': 248388.734467301,
#   'max_supply': None,
#   'ath': 2134.61,
#   'ath_change_percentage': -14.02075,
#   'ath_date': '2023-04-16T19:24:52.171Z',
#   'atl': 1137.25,
#   'atl_change_percentage': 61.38288,
#   'atl_date': '2022-11-23T02:25:33.267Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:21.060Z'},
#  {'id': 'mina-protocol',
#   'symbol': 'mina',
#   'name': 'Mina Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/15628/large/JM4_vQ34_400x400.png?1621394004',
#   'current_price': 0.475512,
#   'market_cap': 452532968,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 505969521,
#   'total_volume': 11610236,
#   'high_24h': 0.491715,
#   'low_24h': 0.47496,
#   'price_change_24h': -0.004310956448705772,
#   'price_change_percentage_24h': -0.89845,
#   'market_cap_change_24h': -4303665.446312547,
#   'market_cap_change_percentage_24h': -0.94206,
#   'circulating_supply': 951290839.840039,
#   'total_supply': 1063622332.84004,
#   'max_supply': None,
#   'ath': 9.09,
#   'ath_change_percentage': -94.76897,
#   'ath_date': '2021-06-01T01:42:37.064Z',
#   'atl': 0.380741,
#   'atl_change_percentage': 24.89305,
#   'atl_date': '2023-06-10T06:00:03.859Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:25.806Z'},
#  {'id': 'terra-luna',
#   'symbol': 'lunc',
#   'name': 'Terra Luna Classic',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/01_LunaClassic_color.png?1653547790',
#   'current_price': 7.752e-05,
#   'market_cap': 450791002,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 530067267,
#   'total_volume': 18393384,
#   'high_24h': 7.949e-05,
#   'low_24h': 7.73e-05,
#   'price_change_24h': -6.02802047702e-07,
#   'price_change_percentage_24h': -0.77163,
#   'market_cap_change_24h': -3727079.0226743817,
#   'market_cap_change_percentage_24h': -0.82001,
#   'circulating_supply': 5816046217610.48,
#   'total_supply': 6838858161188.62,
#   'max_supply': None,
#   'ath': 119.18,
#   'ath_change_percentage': -99.99993,
#   'ath_date': '2022-04-05T12:24:58.854Z',
#   'atl': 9.99967e-07,
#   'atl_change_percentage': 7651.1291,
#   'atl_date': '2022-05-13T02:34:40.340Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:25.758Z'},
#  {'id': 'tokenize-xchange',
#   'symbol': 'tkx',
#   'name': 'Tokenize Xchange',
#   'image': 'https://assets.coingecko.com/coins/images/4984/large/TKX_-_Logo_-_RGB-15.png?1672912391',
#   'current_price': 5.51,
#   'market_cap': 441121072,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 551428912,
#   'total_volume': 7428494,
#   'high_24h': 5.62,
#   'low_24h': 5.48,
#   'price_change_24h': -0.09565881846066304,
#   'price_change_percentage_24h': -1.70516,
#   'market_cap_change_24h': -6848782.940457046,
#   'market_cap_change_percentage_24h': -1.52885,
#   'circulating_supply': 79995999.94518414,
#   'total_supply': 100000000.0,
#   'max_supply': 100000000.0,
#   'ath': 22.3,
#   'ath_change_percentage': -75.2743,
#   'ath_date': '2022-10-31T10:23:59.455Z',
#   'atl': 0.111255,
#   'atl_change_percentage': 4855.20702,
#   'atl_date': '2019-04-28T00:00:00.000Z',
#   'roi': {'times': 17.98206237587344,
#    'currency': 'usd',
#    'percentage': 1798.2062375873438},
#   'last_updated': '2023-08-15T12:41:13.189Z'},
#  {'id': 'bittorrent',
#   'symbol': 'btt',
#   'name': 'BitTorrent',
#   'image': 'https://assets.coingecko.com/coins/images/22457/large/btt_logo.png?1643857231',
#   'current_price': 4.56561e-07,
#   'market_cap': 434245154,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 451852944,
#   'total_volume': 22751672,
#   'high_24h': 4.64018e-07,
#   'low_24h': 4.56116e-07,
#   'price_change_24h': -6.844778832e-09,
#   'price_change_percentage_24h': -1.47706,
#   'market_cap_change_24h': -6818196.573525846,
#   'market_cap_change_percentage_24h': -1.54585,
#   'circulating_supply': 951421714286000.0,
#   'total_supply': 990000000000000.0,
#   'max_supply': 990000000000000.0,
#   'ath': 3.43e-06,
#   'ath_change_percentage': -86.6967,
#   'ath_date': '2022-01-21T04:00:31.909Z',
#   'atl': 4.54469e-07,
#   'atl_change_percentage': 0.44284,
#   'atl_date': '2023-08-07T17:05:11.236Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:28.868Z'},
#  {'id': 'casper-network',
#   'symbol': 'cspr',
#   'name': 'Casper Network',
#   'image': 'https://assets.coingecko.com/coins/images/15279/large/casper.PNG?1620341020',
#   'current_price': 0.03812095,
#   'market_cap': 429444632,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 455853018,
#   'total_volume': 3735910,
#   'high_24h': 0.03944459,
#   'low_24h': 0.03808001,
#   'price_change_24h': -0.000764993965671985,
#   'price_change_percentage_24h': -1.96728,
#   'market_cap_change_24h': -9644181.717255235,
#   'market_cap_change_percentage_24h': -2.19641,
#   'circulating_supply': 11245573528.0,
#   'total_supply': 11937111901.0,
#   'max_supply': None,
#   'ath': 1.33,
#   'ath_change_percentage': -97.12388,
#   'ath_date': '2021-05-12T00:00:00.000Z',
#   'atl': 0.02241297,
#   'atl_change_percentage': 70.08617,
#   'atl_date': '2022-06-18T20:14:44.694Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.637Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://assets.coingecko.com/coins/images/26375/large/sui_asset.jpeg?1683114182',
#   'current_price': 0.588026,
#   'market_cap': 425214084,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 5879926927,
#   'total_volume': 51342306,
#   'high_24h': 0.602818,
#   'low_24h': 0.585526,
#   'price_change_24h': -0.007657072576961799,
#   'price_change_percentage_24h': -1.28543,
#   'market_cap_change_24h': -6317988.221614182,
#   'market_cap_change_percentage_24h': -1.46408,
#   'circulating_supply': 723162190.461538,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.16,
#   'ath_change_percentage': -72.86654,
#   'ath_date': '2023-05-03T12:00:26.430Z',
#   'atl': 0.557963,
#   'atl_change_percentage': 5.16215,
#   'atl_date': '2023-06-10T06:00:47.648Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:31.400Z'},
#  {'id': 'gmx',
#   'symbol': 'gmx',
#   'name': 'GMX',
#   'image': 'https://assets.coingecko.com/coins/images/18323/large/arbit.png?1631532468',
#   'current_price': 46.89,
#   'market_cap': 419730434,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 621380226,
#   'total_volume': 11746406,
#   'high_24h': 47.63,
#   'low_24h': 46.33,
#   'price_change_24h': 0.01492083,
#   'price_change_percentage_24h': 0.03183,
#   'market_cap_change_24h': 180938,
#   'market_cap_change_percentage_24h': 0.04313,
#   'circulating_supply': 8950121.06849897,
#   'total_supply': 8950121.06849897,
#   'max_supply': 13250000.0,
#   'ath': 91.07,
#   'ath_change_percentage': -48.55469,
#   'ath_date': '2023-04-18T10:00:25.680Z',
#   'atl': 11.53,
#   'atl_change_percentage': 306.21262,
#   'atl_date': '2022-06-15T09:30:22.146Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:24.256Z'},
#  {'id': 'huobi-token',
#   'symbol': 'ht',
#   'name': 'Huobi',
#   'image': 'https://assets.coingecko.com/coins/images/2822/large/huobi-token-logo.png?1547036992',
#   'current_price': 2.57,
#   'market_cap': 409368388,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 516313530,
#   'total_volume': 10419691,
#   'high_24h': 2.59,
#   'low_24h': 2.55,
#   'price_change_24h': -0.017297355627877042,
#   'price_change_percentage_24h': -0.66914,
#   'market_cap_change_24h': -2372319.9717624784,
#   'market_cap_change_percentage_24h': -0.57617,
#   'circulating_supply': 159406077.0,
#   'total_supply': 201050000.0,
#   'max_supply': 201050000.0,
#   'ath': 39.66,
#   'ath_change_percentage': -93.52802,
#   'ath_date': '2021-05-12T14:42:21.586Z',
#   'atl': 0.3138,
#   'atl_change_percentage': 717.98537,
#   'atl_date': '2023-03-10T05:05:00+08:00',
#   'roi': {'times': 1.5936438745378556,
#    'currency': 'usd',
#    'percentage': 159.36438745378555},
#   'last_updated': '2023-08-15T12:43:28.962Z'},
#  {'id': 'trust-wallet-token',
#   'symbol': 'twt',
#   'name': 'Trust Wallet',
#   'image': 'https://assets.coingecko.com/coins/images/11085/large/Trust.png?1588062702',
#   'current_price': 0.940249,
#   'market_cap': 391620028,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 939925889,
#   'total_volume': 16765102,
#   'high_24h': 0.968852,
#   'low_24h': 0.918313,
#   'price_change_24h': 0.02182237,
#   'price_change_percentage_24h': 2.37606,
#   'market_cap_change_24h': 8496620,
#   'market_cap_change_percentage_24h': 2.21772,
#   'circulating_supply': 416649900.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 2.72,
#   'ath_change_percentage': -65.44057,
#   'ath_date': '2022-12-11T23:25:46.205Z',
#   'atl': 0.00277641,
#   'atl_change_percentage': 33768.55632,
#   'atl_date': '2020-06-09T09:15:06.983Z',
#   'roi': None,
#   'last_updated': '2023-08-15T12:43:30.770Z'}]

# %%
pd.DataFrame(json.loads(r.text))
# Out:
#                     id symbol            name
# 0              bitcoin    btc         Bitcoin  \
# 1             ethereum    eth        Ethereum
# 2               tether   usdt          Tether
# 3          binancecoin    bnb             BNB
# 4               ripple    xrp             XRP
# ..                 ...    ...             ...
# 95      casper-network   cspr  Casper Network
# 96                 sui    sui             Sui
# 97                 gmx    gmx             GMX
# 98         huobi-token     ht           Huobi
# 99  trust-wallet-token    twt    Trust Wallet
#
#                                                 image  current_price
# 0   https://assets.coingecko.com/coins/images/1/la...   29329.000000  \
# 1   https://assets.coingecko.com/coins/images/279/...    1839.590000
# 2   https://assets.coingecko.com/coins/images/325/...       0.998265
# 3   https://assets.coingecko.com/coins/images/825/...     238.770000
# 4   https://assets.coingecko.com/coins/images/44/l...       0.625757
# ..                                                ...            ...
# 95  https://assets.coingecko.com/coins/images/1527...       0.038121
# 96  https://assets.coingecko.com/coins/images/2637...       0.588026
# 97  https://assets.coingecko.com/coins/images/1832...      46.890000
# 98  https://assets.coingecko.com/coins/images/2822...       2.570000
# 99  https://assets.coingecko.com/coins/images/1108...       0.940249
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume
# 0   570767445551                1             6.159962e+11  9.835851e+09  \
# 1   220998199775                2             2.209982e+11  4.077286e+09
# 2    83266125312                3             8.326613e+10  8.595880e+09
# 3    36735621076                4             4.775320e+10  3.280372e+08
# 4    33035321058                5             6.258197e+10  8.203435e+08
# ..           ...              ...                      ...           ...
# 95     429444632               96             4.558530e+08  3.735910e+06
# 96     425214084               97             5.879927e+09  5.134231e+07
# 97     419730434               98             6.213802e+08  1.174641e+07
# 98     409368388               99             5.163135e+08  1.041969e+07
# 99     391620028              100             9.399259e+08  1.676510e+07
#
#         high_24h  ...  total_supply    max_supply       ath
# 0   29653.000000  ...  2.100000e+07  2.100000e+07  69045.00  \
# 1    1854.610000  ...  1.201422e+08           NaN   4878.26
# 2       1.001000  ...  8.341087e+10           NaN      1.32
# 3     241.000000  ...  1.538562e+08  2.000000e+08    686.31
# 4       0.635508  ...  9.998852e+10  1.000000e+11      3.40
# ..           ...  ...           ...           ...       ...
# 95      0.039445  ...  1.193711e+10           NaN      1.33
# 96      0.602818  ...  1.000000e+10  1.000000e+10      2.16
# 97     47.630000  ...  8.950121e+06  1.325000e+07     91.07
# 98      2.590000  ...  2.010500e+08  2.010500e+08     39.66
# 99      0.968852  ...  1.000000e+09           NaN      2.72
#
#     ath_change_percentage                  ath_date        atl
# 0               -57.51647  2021-11-10T14:24:11.849Z  67.810000  \
# 1               -62.29363  2021-11-10T14:24:19.604Z   0.432979
# 2               -24.55081  2018-07-24T00:00:00.000Z   0.572521
# 3               -65.21001  2021-05-10T07:24:17.097Z   0.039818
# 4               -81.57932  2018-01-07T00:00:00.000Z   0.002686
# ..                    ...                       ...        ...
# 95              -97.12388  2021-05-12T00:00:00.000Z   0.022413
# 96              -72.86654  2023-05-03T12:00:26.430Z   0.557963
# 97              -48.55469  2023-04-18T10:00:25.680Z  11.530000
# 98              -93.52802  2021-05-12T14:42:21.586Z   0.313800
# 99              -65.44057  2022-12-11T23:25:46.205Z   0.002776
#
#     atl_change_percentage                   atl_date
# 0             43157.76454   2013-07-06T00:00:00.000Z  \
# 1            424727.83758   2015-10-20T00:00:00.000Z
# 2                74.36299   2015-03-02T00:00:00.000Z
# 3            599547.99583   2017-10-19T00:00:00.000Z
# 4             23204.88887   2014-05-22T00:00:00.000Z
# ..                    ...                        ...
# 95               70.08617   2022-06-18T20:14:44.694Z
# 96                5.16215   2023-06-10T06:00:47.648Z
# 97              306.21262   2022-06-15T09:30:22.146Z
# 98              717.98537  2023-03-10T05:05:00+08:00
# 99            33768.55632   2020-06-09T09:15:06.983Z
#
#                                                   roi
# 0                                                None  \
# 1   {'times': 82.85810730658314, 'currency': 'btc'...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98  {'times': 1.5936438745378556, 'currency': 'usd...
# 99                                               None
#
#                 last_updated
# 0   2023-08-15T12:43:25.287Z
# 1   2023-08-15T12:43:26.527Z
# 2   2023-08-15T12:40:01.184Z
# 3   2023-08-15T12:43:27.681Z
# 4   2023-08-15T12:43:27.731Z
# ..                       ...
# 95  2023-08-15T12:43:30.637Z
# 96  2023-08-15T12:43:31.400Z
# 97  2023-08-15T12:43:24.256Z
# 98  2023-08-15T12:43:28.962Z
# 99  2023-08-15T12:43:30.770Z
#
# [100 rows x 26 columns]

# %% [markdown]
# Utilizamos la libreria auxiliar de CoinGeckoAPI para asistirnos con las funciones que estan disponibles para consumir la API.

# %%
from pycoingecko import CoinGeckoAPI
# Creemos la funcionalidad de Coin Gecko.
cg = CoinGeckoAPI()

# %% [markdown]
# Vamos a obtener una lista de monedas para quedarnos con las 10 monedas con mejor market cap a la fecha actual.

# %%
coinsMarket = cg.get_coins_markets(vs_currency='usd')
coinsMarket
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 29463,
#   'market_cap': 572976495187,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 618533330585,
#   'total_volume': 13159008031,
#   'high_24h': 29759,
#   'low_24h': 29401,
#   'price_change_24h': -292.3479178016969,
#   'price_change_percentage_24h': -0.98249,
#   'market_cap_change_24h': -5831019461.301392,
#   'market_cap_change_percentage_24h': -1.00742,
#   'circulating_supply': 19453287.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -57.2862,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 43392.22716,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:53.959Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 1853.08,
#   'market_cap': 222531517420,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 222531517420,
#   'total_volume': 5056968116,
#   'high_24h': 1862.32,
#   'low_24h': 1845.7,
#   'price_change_24h': 0.574954,
#   'price_change_percentage_24h': 0.03104,
#   'market_cap_change_24h': -299198821.40689087,
#   'market_cap_change_percentage_24h': -0.13427,
#   'circulating_supply': 120152466.320102,
#   'total_supply': 120152466.320102,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -61.98862,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 428164.32128,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 83.08691412338165,
#    'currency': 'btc',
#    'percentage': 8308.691412338165},
#   'last_updated': '2023-08-10T15:56:56.204Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether.png?1668148663',
#   'current_price': 1.0,
#   'market_cap': 83560430462,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 83560430462,
#   'total_volume': 12182384271,
#   'high_24h': 1.001,
#   'low_24h': 0.997758,
#   'price_change_24h': 0.00091676,
#   'price_change_percentage_24h': 0.09175,
#   'market_cap_change_24h': 236205098,
#   'market_cap_change_percentage_24h': 0.28348,
#   'circulating_supply': 83532928351.1514,
#   'total_supply': 83532928351.1514,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.48006,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.52649,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:55:00.472Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1644979850',
#   'current_price': 242.04,
#   'market_cap': 37231510952,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 48397819590,
#   'total_volume': 333018860,
#   'high_24h': 244.09,
#   'low_24h': 241.61,
#   'price_change_24h': -1.776332557685322,
#   'price_change_percentage_24h': -0.72855,
#   'market_cap_change_24h': -272282905.8103714,
#   'market_cap_change_percentage_24h': -0.72601,
#   'circulating_supply': 153856150.0,
#   'total_supply': 153856150.0,
#   'max_supply': 200000000.0,
#   'ath': 686.31,
#   'ath_change_percentage': -64.69277,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 608463.12406,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:02.697Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 0.631087,
#   'market_cap': 33285362055,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 63110637523,
#   'total_volume': 1384320360,
#   'high_24h': 0.661595,
#   'low_24h': 0.625353,
#   'price_change_24h': -0.02406313671132887,
#   'price_change_percentage_24h': -3.67292,
#   'market_cap_change_24h': -1263359165.251667,
#   'market_cap_change_percentage_24h': -3.65675,
#   'circulating_supply': 52741286353.0,
#   'total_supply': 99988538151.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -81.43142,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 23392.01413,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:03.977Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 1.001,
#   'market_cap': 26174637853,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 26174100135,
#   'total_volume': 2845832378,
#   'high_24h': 1.003,
#   'low_24h': 0.99815,
#   'price_change_24h': 0.00093138,
#   'price_change_percentage_24h': 0.09313,
#   'market_cap_change_24h': -54151027.72797775,
#   'market_cap_change_percentage_24h': -0.20646,
#   'circulating_supply': 26165779710.8967,
#   'total_supply': 26165242175.0744,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.68848,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.99273,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:59.410Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 1851.74,
#   'market_cap': 14882215045,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 14884150428,
#   'total_volume': 26113207,
#   'high_24h': 1862.57,
#   'low_24h': 1843.73,
#   'price_change_24h': -1.4752956898930734,
#   'price_change_percentage_24h': -0.07961,
#   'market_cap_change_24h': 47590099,
#   'market_cap_change_percentage_24h': 0.3208,
#   'circulating_supply': 8034842.21925245,
#   'total_supply': 8035887.12378221,
#   'max_supply': 8035887.12378221,
#   'ath': 4829.57,
#   'ath_change_percentage': -61.6321,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 283.72739,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:54.774Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.076207,
#   'market_cap': 10699492935,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 10699499787,
#   'total_volume': 424173448,
#   'high_24h': 0.076356,
#   'low_24h': 0.074539,
#   'price_change_24h': 0.00112117,
#   'price_change_percentage_24h': 1.49319,
#   'market_cap_change_24h': 135814649,
#   'market_cap_change_percentage_24h': 1.28568,
#   'circulating_supply': 140534306383.705,
#   'total_supply': 140534396383.705,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -89.56329,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 87758.90435,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:56.941Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 0.29753,
#   'market_cap': 10424600327,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 13385839231,
#   'total_volume': 198173108,
#   'high_24h': 0.301925,
#   'low_24h': 0.296878,
#   'price_change_24h': -0.000469599648526442,
#   'price_change_percentage_24h': -0.15758,
#   'market_cap_change_24h': -25831938.213697433,
#   'market_cap_change_percentage_24h': -0.24719,
#   'circulating_supply': 35045020830.3234,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -90.35128,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 1447.03822,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:56.144Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/solana.png?1640133422',
#   'current_price': 24.53,
#   'market_cap': 9958472327,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 13610155208,
#   'total_volume': 371291680,
#   'high_24h': 24.78,
#   'low_24h': 24.15,
#   'price_change_24h': -0.02444385116453418,
#   'price_change_percentage_24h': -0.09956,
#   'market_cap_change_24h': -12324607.90712738,
#   'market_cap_change_percentage_24h': -0.12361,
#   'circulating_supply': 405782064.913137,
#   'total_supply': 554578724.784854,
#   'max_supply': None,
#   'ath': 259.96,
#   'ath_change_percentage': -90.55194,
#   'ath_date': '2021-11-06T21:54:35.825Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 4804.3617,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:58.848Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.077219,
#   'market_cap': 6908213441,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 6908210394,
#   'total_volume': 177629347,
#   'high_24h': 0.077454,
#   'low_24h': 0.07618,
#   'price_change_24h': 0.00080946,
#   'price_change_percentage_24h': 1.05937,
#   'market_cap_change_24h': 78399500,
#   'market_cap_change_percentage_24h': 1.1479,
#   'circulating_supply': 89508219007.2128,
#   'total_supply': 89508179523.8285,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -66.70213,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 4175.36017,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 39.641325918637406,
#    'currency': 'usd',
#    'percentage': 3964.1325918637403},
#   'last_updated': '2023-08-10T15:56:57.845Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 0.688145,
#   'market_cap': 6413566709,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 6881901385,
#   'total_volume': 247814737,
#   'high_24h': 0.699026,
#   'low_24h': 0.683016,
#   'price_change_24h': 0.00167806,
#   'price_change_percentage_24h': 0.24445,
#   'market_cap_change_24h': 19776547,
#   'market_cap_change_percentage_24h': 0.30931,
#   'circulating_supply': 9319469069.28493,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.92,
#   'ath_change_percentage': -76.38196,
#   'ath_date': '2021-12-27T02:08:34.307Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 21808.92678,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 260.6522040735139,
#    'currency': 'usd',
#    'percentage': 26065.22040735139},
#   'last_updated': '2023-08-10T15:56:57.599Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/polkadot.png?1639712644',
#   'current_price': 5.01,
#   'market_cap': 6325670739,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 6731420130,
#   'total_volume': 91291492,
#   'high_24h': 5.06,
#   'low_24h': 4.99,
#   'price_change_24h': -0.03844828725631455,
#   'price_change_percentage_24h': -0.76162,
#   'market_cap_change_24h': -40851293.94729614,
#   'market_cap_change_percentage_24h': -0.64166,
#   'circulating_supply': 1262598247.88597,
#   'total_supply': 1343585464.96731,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -90.88976,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 85.68947,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:02.548Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 83.42,
#   'market_cap': 6137556003,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 7011831589,
#   'total_volume': 341715999,
#   'high_24h': 84.27,
#   'low_24h': 83.19,
#   'price_change_24h': -0.1643594918136273,
#   'price_change_percentage_24h': -0.19663,
#   'market_cap_change_24h': -3768602.2018699646,
#   'market_cap_change_percentage_24h': -0.06136,
#   'circulating_supply': 73526395.7334713,
#   'total_supply': 84000000.0,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -79.64771,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 7167.94899,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:03.567Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 9.92e-06,
#   'market_cap': 5847426285,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 9921927511,
#   'total_volume': 318092879,
#   'high_24h': 1.008e-05,
#   'low_24h': 9.44e-06,
#   'price_change_24h': 2.21153e-07,
#   'price_change_percentage_24h': 2.27917,
#   'market_cap_change_24h': 119885264,
#   'market_cap_change_percentage_24h': 2.09314,
#   'circulating_supply': 589336566984388.0,
#   'total_supply': 999987757453269.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -88.47666,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 17613898.95225,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:56.500Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 29481,
#   'market_cap': 4781524527,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 4781524527,
#   'total_volume': 76073631,
#   'high_24h': 29742,
#   'low_24h': 29428,
#   'price_change_24h': -204.91406764142448,
#   'price_change_percentage_24h': -0.69027,
#   'market_cap_change_24h': -41048746.9632864,
#   'market_cap_change_percentage_24h': -0.85118,
#   'circulating_supply': 162105.58767567,
#   'total_supply': 162105.58767567,
#   'max_supply': 162105.58767567,
#   'ath': 70643,
#   'ath_change_percentage': -58.23557,
#   'ath_date': '2021-11-10T14:40:19.650Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 839.85949,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:03.835Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uni.jpg?1687143398',
#   'current_price': 6.2,
#   'market_cap': 4663796192,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 6187320819,
#   'total_volume': 110433857,
#   'high_24h': 6.32,
#   'low_24h': 6.1,
#   'price_change_24h': 0.085424,
#   'price_change_percentage_24h': 1.39692,
#   'market_cap_change_24h': 63946399,
#   'market_cap_change_percentage_24h': 1.39018,
#   'circulating_supply': 753766667.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -86.22879,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 500.45953,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:56.988Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 233.31,
#   'market_cap': 4538596770,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 4894612871,
#   'total_volume': 252467405,
#   'high_24h': 239.84,
#   'low_24h': 232.57,
#   'price_change_24h': -3.5815498792887013,
#   'price_change_percentage_24h': -1.5119,
#   'market_cap_change_24h': -69990089.84422016,
#   'market_cap_change_percentage_24h': -1.51869,
#   'circulating_supply': 19472537.3966508,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -93.8387,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 203.18641,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:01.316Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://assets.coingecko.com/coins/images/17980/large/ton_symbol.png?1670498136',
#   'current_price': 1.26,
#   'market_cap': 4326514418,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 6406989109,
#   'total_volume': 22593159,
#   'high_24h': 1.29,
#   'low_24h': 1.24,
#   'price_change_24h': -0.015972674246565788,
#   'price_change_percentage_24h': -1.25321,
#   'market_cap_change_24h': -49299173.64783573,
#   'market_cap_change_percentage_24h': -1.12663,
#   'circulating_supply': 3438223313.8108,
#   'total_supply': 5091548807.53446,
#   'max_supply': None,
#   'ath': 5.29,
#   'ath_change_percentage': -76.21827,
#   'ath_date': '2021-11-12T06:50:02.476Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 142.26615,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:57.386Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1670992574',
#   'current_price': 12.54,
#   'market_cap': 4308544865,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 9022788050,
#   'total_volume': 112811893,
#   'high_24h': 12.64,
#   'low_24h': 12.47,
#   'price_change_24h': -0.0884397733248754,
#   'price_change_percentage_24h': -0.70017,
#   'market_cap_change_24h': -40037528.951660156,
#   'market_cap_change_percentage_24h': -0.9207,
#   'circulating_supply': 343813052.657463,
#   'total_supply': 430532544.770418,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -91.35216,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 347.54489,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:57.137Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 7.67,
#   'market_cap': 4129239567,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 7673740545,
#   'total_volume': 283712942,
#   'high_24h': 7.74,
#   'low_24h': 7.57,
#   'price_change_24h': -0.04278190995204234,
#   'price_change_percentage_24h': -0.55466,
#   'market_cap_change_24h': -31289602.024442673,
#   'market_cap_change_percentage_24h': -0.75206,
#   'circulating_supply': 538099971.2305644,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -85.42238,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 5084.06425,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:03.884Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/Badge_Dai.png?1687143508',
#   'current_price': 1.0,
#   'market_cap': 4009546901,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 4010255434,
#   'total_volume': 111943832,
#   'high_24h': 1.002,
#   'low_24h': 0.997812,
#   'price_change_24h': 0.00047775,
#   'price_change_percentage_24h': 0.04779,
#   'market_cap_change_24h': -38655079.70493889,
#   'market_cap_change_percentage_24h': -0.95487,
#   'circulating_supply': 4007910237.30728,
#   'total_supply': 4008618480.92736,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.91167,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.45184,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:55:00.180Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.140065,
#   'market_cap': 3832587530,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 7002265875,
#   'total_volume': 98231572,
#   'high_24h': 0.142911,
#   'low_24h': 0.138602,
#   'price_change_24h': -0.002845978179446707,
#   'price_change_percentage_24h': -1.99144,
#   'market_cap_change_24h': -77189449.51836395,
#   'market_cap_change_percentage_24h': -1.97427,
#   'circulating_supply': 27367744913.2687,
#   'total_supply': 50001787251.4736,
#   'max_supply': 50001787251.4736,
#   'ath': 0.875563,
#   'ath_change_percentage': -83.98339,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 29353.61153,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:58.375Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://assets.coingecko.com/coins/images/8418/large/leo-token.png?1558326215',
#   'current_price': 4.0,
#   'market_cap': 3717649996,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 3939909423,
#   'total_volume': 1368936,
#   'high_24h': 4.01,
#   'low_24h': 3.93,
#   'price_change_24h': 0.01102317,
#   'price_change_percentage_24h': 0.27628,
#   'market_cap_change_24h': -2948953.5453953743,
#   'market_cap_change_percentage_24h': -0.07926,
#   'circulating_supply': 929659858.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 8.14,
#   'ath_change_percentage': -50.8895,
#   'ath_date': '2022-02-08T17:40:10.285Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 399.50144,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:53.352Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 0.999992,
#   'market_cap': 3389530611,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 3389530611,
#   'total_volume': 1753048740,
#   'high_24h': 1.003,
#   'low_24h': 0.995025,
#   'price_change_24h': -0.00166491118923584,
#   'price_change_percentage_24h': -0.16622,
#   'market_cap_change_24h': -12870568.225774288,
#   'market_cap_change_percentage_24h': -0.37828,
#   'circulating_supply': 3391737664.66,
#   'total_supply': 3391737664.66,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.29753,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 11.0524,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:00.972Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'image': 'https://assets.coingecko.com/coins/images/3449/large/tusd.png?1618395665',
#   'current_price': 1.001,
#   'market_cap': 2980752174,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 2978301987,
#   'total_volume': 332217945,
#   'high_24h': 1.002,
#   'low_24h': 0.994874,
#   'price_change_24h': 0.00145944,
#   'price_change_percentage_24h': 0.14608,
#   'market_cap_change_24h': -7593142.421141148,
#   'market_cap_change_percentage_24h': -0.25409,
#   'circulating_supply': 2980524781.45,
#   'total_supply': 2978074781.45,
#   'max_supply': None,
#   'ath': 1.62,
#   'ath_change_percentage': -38.25036,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 0.88355,
#   'atl_change_percentage': 13.11481,
#   'atl_date': '2020-03-12T10:47:51.380Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:57.098Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1642471050',
#   'current_price': 48.38,
#   'market_cap': 2901298323,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 14506491617,
#   'total_volume': 8706833,
#   'high_24h': 48.8,
#   'low_24h': 47.6,
#   'price_change_24h': 0.240099,
#   'price_change_percentage_24h': 0.49878,
#   'market_cap_change_24h': 20828142,
#   'market_cap_change_percentage_24h': 0.72308,
#   'circulating_supply': 60000000.0,
#   'total_supply': 235957685.3,
#   'max_supply': 300000000.0,
#   'ath': 58.66,
#   'ath_change_percentage': -17.65295,
#   'ath_date': '2023-02-18T01:21:37.582Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 8219.49471,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:58.461Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 154.98,
#   'market_cap': 2811110749,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': None,
#   'total_volume': 89000027,
#   'high_24h': 158.38,
#   'low_24h': 154.48,
#   'price_change_24h': -3.3972134594599197,
#   'price_change_percentage_24h': -2.14498,
#   'market_cap_change_24h': -58098073.21574783,
#   'market_cap_change_percentage_24h': -2.02488,
#   'circulating_supply': 18147820.3764146,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -71.41534,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 71610.75431,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:59.999Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 17.68,
#   'market_cap': 2515545908,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 3721611242,
#   'total_volume': 74863818,
#   'high_24h': 17.88,
#   'low_24h': 17.67,
#   'price_change_24h': -0.16819385537714027,
#   'price_change_percentage_24h': -0.94232,
#   'market_cap_change_24h': -26131975.25295639,
#   'market_cap_change_percentage_24h': -1.02814,
#   'circulating_supply': 142418293.643882,
#   'total_supply': 210700000.0,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -89.41087,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 2776.71402,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 38.290550869127664,
#    'currency': 'usd',
#    'percentage': 3829.0550869127665},
#   'last_updated': '2023-08-10T15:56:55.210Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos Hub',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 8.48,
#   'market_cap': 2479877726,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': None,
#   'total_volume': 194578850,
#   'high_24h': 8.55,
#   'low_24h': 8.43,
#   'price_change_24h': -0.06687981055338277,
#   'price_change_percentage_24h': -0.78251,
#   'market_cap_change_24h': -22712682.259349346,
#   'market_cap_change_percentage_24h': -0.90757,
#   'circulating_supply': 292586163.827428,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 44.45,
#   'ath_change_percentage': -80.93451,
#   'ath_date': '2022-01-17T00:34:41.497Z',
#   'atl': 1.16,
#   'atl_change_percentage': 630.50022,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 83.79999414787682,
#    'currency': 'usd',
#    'percentage': 8379.99941478768},
#   'last_updated': '2023-08-10T15:57:00.389Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://assets.coingecko.com/coins/images/3688/large/hbar.png?1637045634',
#   'current_price': 0.057833,
#   'market_cap': 1884914629,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 2894567030,
#   'total_volume': 41895833,
#   'high_24h': 0.060992,
#   'low_24h': 0.057635,
#   'price_change_24h': -0.002830194104196556,
#   'price_change_percentage_24h': -4.66541,
#   'market_cap_change_24h': -92522931.72893906,
#   'market_cap_change_percentage_24h': -4.67893,
#   'circulating_supply': 32559526344.5686,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -89.8285,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 487.14601,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:55.661Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 4.14,
#   'market_cap': 1818586218,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 8107109140,
#   'total_volume': 76242653,
#   'high_24h': 4.16,
#   'low_24h': 4.09,
#   'price_change_24h': -0.003962190157751345,
#   'price_change_percentage_24h': -0.0957,
#   'market_cap_change_24h': -3163109.223065853,
#   'market_cap_change_percentage_24h': -0.17363,
#   'circulating_supply': 440034133.0,
#   'total_supply': 1961636301.0,
#   'max_supply': 1961636301.0,
#   'ath': 236.84,
#   'ath_change_percentage': -98.25467,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 2.64,
#   'atl_change_percentage': 56.51963,
#   'atl_date': '2022-12-16T22:45:28.552Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:55.660Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 4.02,
#   'market_cap': 1773582191,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 1887263045,
#   'total_volume': 22113651,
#   'high_24h': 4.1,
#   'low_24h': 4.01,
#   'price_change_24h': -0.055050121245209915,
#   'price_change_percentage_24h': -1.35068,
#   'market_cap_change_24h': -22423093.014891386,
#   'market_cap_change_percentage_24h': -1.2485,
#   'circulating_supply': 440950233.118578,
#   'total_supply': 503293480.989652,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -99.42643,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 3.4,
#   'atl_change_percentage': 18.23135,
#   'atl_date': '2022-12-19T22:45:01.729Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:01.871Z'},
#  {'id': 'lido-dao',
#   'symbol': 'ldo',
#   'name': 'Lido DAO',
#   'image': 'https://assets.coingecko.com/coins/images/13573/large/Lido_DAO.png?1609873644',
#   'current_price': 1.88,
#   'market_cap': 1649944944,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 1877440244,
#   'total_volume': 52402195,
#   'high_24h': 1.93,
#   'low_24h': 1.85,
#   'price_change_24h': 0.00893205,
#   'price_change_percentage_24h': 0.47825,
#   'market_cap_change_24h': 11628516,
#   'market_cap_change_percentage_24h': 0.70978,
#   'circulating_supply': 878826875.756457,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 7.3,
#   'ath_change_percentage': -74.28331,
#   'ath_date': '2021-08-20T08:35:20.158Z',
#   'atl': 0.40615,
#   'atl_change_percentage': 362.40502,
#   'atl_date': '2022-06-18T20:55:12.035Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:03.520Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'image': 'https://assets.coingecko.com/coins/images/26455/large/aptos_round.png?1666839629',
#   'current_price': 7.34,
#   'market_cap': 1611613240,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 7683864355,
#   'total_volume': 356202957,
#   'high_24h': 7.56,
#   'low_24h': 7.26,
#   'price_change_24h': -0.020441275654699886,
#   'price_change_percentage_24h': -0.27764,
#   'market_cap_change_24h': -1637741.300107956,
#   'market_cap_change_percentage_24h': -0.10152,
#   'circulating_supply': 220050608.286932,
#   'total_supply': 1049159304.23473,
#   'max_supply': None,
#   'ath': 19.92,
#   'ath_change_percentage': -63.19137,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 3.08,
#   'atl_change_percentage': 138.08159,
#   'atl_date': '2022-12-29T21:35:14.796Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:55.292Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cro_token_logo.png?1669699773',
#   'current_price': 0.057566,
#   'market_cap': 1509900176,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 1728448791,
#   'total_volume': 5637973,
#   'high_24h': 0.057879,
#   'low_24h': 0.057181,
#   'price_change_24h': -0.000172960156894664,
#   'price_change_percentage_24h': -0.29955,
#   'market_cap_change_24h': -3223325.7580549717,
#   'market_cap_change_percentage_24h': -0.21302,
#   'circulating_supply': 26206738386.0306,
#   'total_supply': 30000000000.0,
#   'max_supply': None,
#   'ath': 0.965407,
#   'ath_change_percentage': -94.0372,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 374.97671,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:03.671Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://assets.coingecko.com/coins/images/30980/large/token-logo.png?1689320029',
#   'current_price': 0.464007,
#   'market_cap': 1501031985,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 2886400414,
#   'total_volume': 15324082,
#   'high_24h': 0.466808,
#   'low_24h': 0.462021,
#   'price_change_24h': -0.002580246031010369,
#   'price_change_percentage_24h': -0.553,
#   'market_cap_change_24h': -5932348.230297565,
#   'market_cap_change_percentage_24h': -0.39366,
#   'circulating_supply': 3234268324.76314,
#   'total_supply': 6219316794.99,
#   'max_supply': 6219316794.99,
#   'ath': 0.600075,
#   'ath_change_percentage': -22.65864,
#   'ath_date': '2023-07-20T22:39:30.228Z',
#   'atl': 0.45061,
#   'atl_change_percentage': 2.99501,
#   'atl_date': '2023-08-08T23:34:42.573Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:44.284Z'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'image': 'https://assets.coingecko.com/coins/images/16547/large/photo_2023-03-29_21.47.00.jpeg?1680097630',
#   'current_price': 1.17,
#   'market_cap': 1488006878,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 11670642182,
#   'total_volume': 183679371,
#   'high_24h': 1.19,
#   'low_24h': 1.17,
#   'price_change_24h': -0.012462634792534288,
#   'price_change_percentage_24h': -1.05603,
#   'market_cap_change_24h': -14899953.461937904,
#   'market_cap_change_percentage_24h': -0.99141,
#   'circulating_supply': 1275000000.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 8.67,
#   'ath_change_percentage': -86.52316,
#   'ath_date': '2023-03-23T13:10:03.106Z',
#   'atl': 0.912886,
#   'atl_change_percentage': 28.04246,
#   'atl_date': '2023-06-15T07:25:14.752Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:00.380Z'},
#  {'id': 'quant-network',
#   'symbol': 'qnt',
#   'name': 'Quant',
#   'image': 'https://assets.coingecko.com/coins/images/3370/large/5ZOu7brX_400x400.jpg?1612437252',
#   'current_price': 101.69,
#   'market_cap': 1477075091,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 1484013201,
#   'total_volume': 21925929,
#   'high_24h': 102.74,
#   'low_24h': 100.98,
#   'price_change_24h': 0.511217,
#   'price_change_percentage_24h': 0.50527,
#   'market_cap_change_24h': 6480592,
#   'market_cap_change_percentage_24h': 0.44068,
#   'circulating_supply': 14544176.164091088,
#   'total_supply': 14612493.0,
#   'max_supply': 14612493.0,
#   'ath': 427.42,
#   'ath_change_percentage': -76.22455,
#   'ath_date': '2021-09-11T09:15:00.668Z',
#   'atl': 0.215773,
#   'atl_change_percentage': 46996.45832,
#   'atl_date': '2018-08-23T00:00:00.000Z',
#   'roi': {'times': 22.595919311127,
#    'currency': 'eth',
#    'percentage': 2259.5919311126995},
#   'last_updated': '2023-08-10T15:56:54.323Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VET_Token_Icon.png?1680067517',
#   'current_price': 0.0180884,
#   'market_cap': 1312448723,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 1565105447,
#   'total_volume': 32517558,
#   'high_24h': 0.01814551,
#   'low_24h': 0.01770399,
#   'price_change_24h': 0.00016417,
#   'price_change_percentage_24h': 0.91591,
#   'market_cap_change_24h': 10151345,
#   'market_cap_change_percentage_24h': 0.7795,
#   'circulating_supply': 72714516834.0,
#   'total_supply': 85985041177.0,
#   'max_supply': 86712634466.0,
#   'ath': 0.280991,
#   'ath_change_percentage': -93.58348,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 840.45816,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 2.416412529123177,
#    'currency': 'eth',
#    'percentage': 241.64125291231773},
#   'last_updated': '2023-08-10T15:56:59.958Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/10365/large/near.jpg?1683515160',
#   'current_price': 1.33,
#   'market_cap': 1254765556,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 1332487531,
#   'total_volume': 48867556,
#   'high_24h': 1.35,
#   'low_24h': 1.33,
#   'price_change_24h': -0.011637707672390809,
#   'price_change_percentage_24h': -0.86494,
#   'market_cap_change_24h': -10975249.867304564,
#   'market_cap_change_percentage_24h': -0.8671,
#   'circulating_supply': 941671517.686093,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -93.47967,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 152.98558,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:58.597Z'},
#  {'id': 'optimism',
#   'symbol': 'op',
#   'name': 'Optimism',
#   'image': 'https://assets.coingecko.com/coins/images/25244/large/Optimism.png?1660904599',
#   'current_price': 1.58,
#   'market_cap': 1132772868,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 6788282347,
#   'total_volume': 145280075,
#   'high_24h': 1.63,
#   'low_24h': 1.53,
#   'price_change_24h': -0.05247412080889924,
#   'price_change_percentage_24h': -3.21694,
#   'market_cap_change_24h': -35224948.502923965,
#   'market_cap_change_percentage_24h': -3.01584,
#   'circulating_supply': 716708907.0,
#   'total_supply': 4294967296.0,
#   'max_supply': 4294967296.0,
#   'ath': 3.22,
#   'ath_change_percentage': -51.05784,
#   'ath_date': '2023-02-24T20:20:00.509Z',
#   'atl': 0.402159,
#   'atl_change_percentage': 292.25717,
#   'atl_date': '2022-06-18T20:54:52.178Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:00.114Z'},
#  {'id': 'maker',
#   'symbol': 'mkr',
#   'name': 'Maker',
#   'image': 'https://assets.coingecko.com/coins/images/1364/large/Mark_Maker.png?1585191826',
#   'current_price': 1252.79,
#   'market_cap': 1127925104,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 1258406486,
#   'total_volume': 157040156,
#   'high_24h': 1259.23,
#   'low_24h': 1194.37,
#   'price_change_24h': 52.62,
#   'price_change_percentage_24h': 4.38449,
#   'market_cap_change_24h': 48324452,
#   'market_cap_change_percentage_24h': 4.47614,
#   'circulating_supply': 901310.9472893132,
#   'total_supply': 977631.036950888,
#   'max_supply': 1005577.0,
#   'ath': 6292.31,
#   'ath_change_percentage': -80.04964,
#   'ath_date': '2021-05-03T21:54:29.333Z',
#   'atl': 168.36,
#   'atl_change_percentage': 645.63882,
#   'atl_date': '2020-03-16T20:52:36.527Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:57.280Z'},
#  {'id': 'rocket-pool-eth',
#   'symbol': 'reth',
#   'name': 'Rocket Pool ETH',
#   'image': 'https://assets.coingecko.com/coins/images/20764/large/reth.png?1637652366',
#   'current_price': 2012.38,
#   'market_cap': 1006472092,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 1006472092,
#   'total_volume': 6418839,
#   'high_24h': 2024.44,
#   'low_24h': 2005.28,
#   'price_change_24h': -2.2666364059298303,
#   'price_change_percentage_24h': -0.11251,
#   'market_cap_change_24h': -402287.9789994955,
#   'market_cap_change_percentage_24h': -0.03995,
#   'circulating_supply': 500001.226195187,
#   'total_supply': 500001.226195187,
#   'max_supply': None,
#   'ath': 4814.31,
#   'ath_change_percentage': -58.17775,
#   'ath_date': '2021-12-01T08:03:50.749Z',
#   'atl': 887.26,
#   'atl_change_percentage': 126.9284,
#   'atl_date': '2022-06-18T20:55:45.957Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:32.509Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 0.107852,
#   'market_cap': 982699854,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 1076848426,
#   'total_volume': 59986324,
#   'high_24h': 0.108563,
#   'low_24h': 0.106494,
#   'price_change_24h': 4.763e-05,
#   'price_change_percentage_24h': 0.04418,
#   'market_cap_change_24h': -664547.4673768282,
#   'market_cap_change_percentage_24h': -0.06758,
#   'circulating_supply': 9125702658.20711,
#   'total_supply': 10000000000.0,
#   'max_supply': None,
#   'ath': 2.84,
#   'ath_change_percentage': -96.2131,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.052051,
#   'atl_change_percentage': 106.72975,
#   'atl_date': '2022-11-22T10:05:03.503Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:02.936Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 67.69,
#   'market_cap': 981411170,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 1082051100,
#   'total_volume': 88949118,
#   'high_24h': 69.13,
#   'low_24h': 66.02,
#   'price_change_24h': 0.904962,
#   'price_change_percentage_24h': 1.35509,
#   'market_cap_change_24h': 13674693,
#   'market_cap_change_percentage_24h': 1.41306,
#   'circulating_supply': 14511864.285647213,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -89.76018,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 160.36773,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:02.460Z'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'image': 'https://assets.coingecko.com/coins/images/2912/large/xdc-icon.png?1633700890',
#   'current_price': 0.069801,
#   'market_cap': 968911322,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 2647254584,
#   'total_volume': 19646748,
#   'high_24h': 0.073072,
#   'low_24h': 0.060774,
#   'price_change_24h': 0.0068674,
#   'price_change_percentage_24h': 10.91206,
#   'market_cap_change_24h': 98907566,
#   'market_cap_change_percentage_24h': 11.36864,
#   'circulating_supply': 13855254229.05,
#   'total_supply': 37855255094.85,
#   'max_supply': None,
#   'ath': 0.192754,
#   'ath_change_percentage': -63.65484,
#   'ath_date': '2021-08-21T04:39:48.324Z',
#   'atl': 0.00039532,
#   'atl_change_percentage': 17621.62694,
#   'atl_date': '2019-07-22T00:00:00.000Z',
#   'roi': {'times': 4.008970376667742,
#    'currency': 'eth',
#    'percentage': 400.8970376667742},
#   'last_updated': '2023-08-10T15:56:54.400Z'},
#  {'id': 'kaspa',
#   'symbol': 'kas',
#   'name': 'Kaspa',
#   'image': 'https://assets.coingecko.com/coins/images/25751/large/kaspa-icon-exchanges.png?1653891958',
#   'current_price': 0.04461791,
#   'market_cap': 897262882,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 1282187940,
#   'total_volume': 21259908,
#   'high_24h': 0.04732471,
#   'low_24h': 0.0443015,
#   'price_change_24h': -0.001879091123758309,
#   'price_change_percentage_24h': -4.04132,
#   'market_cap_change_24h': -35071211.276527405,
#   'market_cap_change_percentage_24h': -3.76166,
#   'circulating_supply': 20086803831.9335,
#   'total_supply': 20086922600.1436,
#   'max_supply': 28704026601.0,
#   'ath': 0.051714,
#   'ath_change_percentage': -13.71417,
#   'ath_date': '2023-08-06T12:10:40.416Z',
#   'atl': 0.00017105,
#   'atl_change_percentage': 25987.10111,
#   'atl_date': '2022-05-26T14:42:59.316Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:00.684Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 0.112195,
#   'market_cap': 875938824,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 1121494896,
#   'total_volume': 32857346,
#   'high_24h': 0.113331,
#   'low_24h': 0.111322,
#   'price_change_24h': -0.000194794376187524,
#   'price_change_percentage_24h': -0.17332,
#   'market_cap_change_24h': -3006360.173008561,
#   'market_cap_change_percentage_24h': -0.34204,
#   'circulating_supply': 7810457518.01808,
#   'total_supply': 7810457512.86308,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -96.84717,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.098399,
#   'atl_change_percentage': 14.10398,
#   'atl_date': '2023-06-10T04:31:46.997Z',
#   'roi': {'times': -0.9532519672922871,
#    'currency': 'usd',
#    'percentage': -95.32519672922871},
#   'last_updated': '2023-08-10T15:57:03.919Z'},
#  {'id': 'havven',
#   'symbol': 'snx',
#   'name': 'Synthetix Network',
#   'image': 'https://assets.coingecko.com/coins/images/3406/large/SNX.png?1598631139',
#   'current_price': 2.59,
#   'market_cap': 832820729,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 834694170,
#   'total_volume': 43211462,
#   'high_24h': 2.65,
#   'low_24h': 2.57,
#   'price_change_24h': -0.002767032531432623,
#   'price_change_percentage_24h': -0.1069,
#   'market_cap_change_24h': -1141529.6006680727,
#   'market_cap_change_percentage_24h': -0.13688,
#   'circulating_supply': 321806453.13952357,
#   'total_supply': 322530361.088774,
#   'max_supply': 322530361.088774,
#   'ath': 28.53,
#   'ath_change_percentage': -90.91397,
#   'ath_date': '2021-02-14T01:12:38.505Z',
#   'atl': 0.0347864,
#   'atl_change_percentage': 7352.48984,
#   'atl_date': '2019-01-06T00:00:00.000Z',
#   'roi': {'times': 4.171153095015422,
#    'currency': 'usd',
#    'percentage': 417.1153095015422},
#   'last_updated': '2023-08-10T15:57:03.386Z'},
#  {'id': 'the-sandbox',
#   'symbol': 'sand',
#   'name': 'The Sandbox',
#   'image': 'https://assets.coingecko.com/coins/images/12129/large/sandbox_logo.jpg?1597397942',
#   'current_price': 0.403545,
#   'market_cap': 830437150,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 1210589824,
#   'total_volume': 75040035,
#   'high_24h': 0.407667,
#   'low_24h': 0.402205,
#   'price_change_24h': -0.002425220978488019,
#   'price_change_percentage_24h': -0.59739,
#   'market_cap_change_24h': -4865772.772924542,
#   'market_cap_change_percentage_24h': -0.58252,
#   'circulating_supply': 2057931926.2233226,
#   'total_supply': 3000000000.0,
#   'max_supply': 3000000000.0,
#   'ath': 8.4,
#   'ath_change_percentage': -95.19209,
#   'ath_date': '2021-11-25T06:04:40.957Z',
#   'atl': 0.02897764,
#   'atl_change_percentage': 1293.17993,
#   'atl_date': '2020-11-04T15:59:14.441Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:58.825Z'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'image': 'https://assets.coingecko.com/coins/images/2069/large/Stacks_logo_full.png?1604112510',
#   'current_price': 0.581766,
#   'market_cap': 813200658,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 1057462065,
#   'total_volume': 10700253,
#   'high_24h': 0.593132,
#   'low_24h': 0.579938,
#   'price_change_24h': -0.010714076309434996,
#   'price_change_percentage_24h': -1.80834,
#   'market_cap_change_24h': -18339882.192855358,
#   'market_cap_change_percentage_24h': -2.20553,
#   'circulating_supply': 1398063198.91431,
#   'total_supply': 1818000000.0,
#   'max_supply': 1818000000.0,
#   'ath': 3.39,
#   'ath_change_percentage': -82.81095,
#   'ath_date': '2021-12-01T01:32:34.725Z',
#   'atl': 0.04559639,
#   'atl_change_percentage': 1177.83387,
#   'atl_date': '2020-03-13T02:29:26.415Z',
#   'roi': {'times': 3.8480516748945908,
#    'currency': 'usd',
#    'percentage': 384.8051674894591},
#   'last_updated': '2023-08-10T15:57:02.078Z'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Frax',
#   'image': 'https://assets.coingecko.com/coins/images/13422/large/FRAX_icon.png?1679886922',
#   'current_price': 0.998904,
#   'market_cap': 810666530,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 810666530,
#   'total_volume': 6206884,
#   'high_24h': 1.001,
#   'low_24h': 0.996143,
#   'price_change_24h': -4.7258843612785e-05,
#   'price_change_percentage_24h': -0.00473,
#   'market_cap_change_24h': -1657584.5828428268,
#   'market_cap_change_percentage_24h': -0.20405,
#   'circulating_supply': 812641409.408784,
#   'total_supply': 812641409.408784,
#   'max_supply': None,
#   'ath': 1.14,
#   'ath_change_percentage': -12.43044,
#   'ath_date': '2021-02-07T12:55:35.766Z',
#   'atl': 0.874536,
#   'atl_change_percentage': 14.1963,
#   'atl_date': '2023-03-11T07:50:39.316Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:53.627Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://assets.coingecko.com/coins/images/27045/large/wbt_token.png?1667923752',
#   'current_price': 5.55,
#   'market_cap': 800677226,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 2222274396,
# ...
#   'current_price': 0.15617,
#   'market_cap': 498946876,
#   'market_cap_rank': 83,
#   'fully_diluted_valuation': None,
#   'total_volume': 4480547,
#   'high_24h': 0.15718,
#   'low_24h': 0.15496,
#   'price_change_24h': -0.000578928838552595,
#   'price_change_percentage_24h': -0.36934,
#   'market_cap_change_24h': -1778337.1500715613,
#   'market_cap_change_percentage_24h': -0.35515,
#   'circulating_supply': 3196694983.0609,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -96.40391,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 158.16077,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:55.763Z'},
#  {'id': 'rollbit-coin',
#   'symbol': 'rlb',
#   'name': 'Rollbit Coin',
#   'image': 'https://assets.coingecko.com/coins/images/24552/large/unziL6wO_400x400.jpg?1648134494',
#   'current_price': 0.150465,
#   'market_cap': 496149453,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 752436660,
#   'total_volume': 13363736,
#   'high_24h': 0.162917,
#   'low_24h': 0.144084,
#   'price_change_24h': -0.01010300294576394,
#   'price_change_percentage_24h': -6.29203,
#   'market_cap_change_24h': -30045154.72221446,
#   'market_cap_change_percentage_24h': -5.70989,
#   'circulating_supply': 3296951621.59,
#   'total_supply': 3296951622.0,
#   'max_supply': 5000000000.0,
#   'ath': 0.179193,
#   'ath_change_percentage': -15.66169,
#   'ath_date': '2023-08-09T06:15:35.847Z',
#   'atl': 0.00093506,
#   'atl_change_percentage': 16062.41142,
#   'atl_date': '2022-07-02T02:46:34.730Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:56.135Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth.png?1687143191',
#   'current_price': 37.19,
#   'market_cap': 493995756,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 493995756,
#   'total_volume': 5439.7,
#   'high_24h': 37.41,
#   'low_24h': 37.08,
#   'price_change_24h': -0.0452553088856007,
#   'price_change_percentage_24h': -0.12155,
#   'market_cap_change_24h': -2945412.9391202927,
#   'market_cap_change_percentage_24h': -0.59271,
#   'circulating_supply': 13284581.7749011,
#   'total_supply': 13284581.7749011,
#   'max_supply': None,
#   'ath': 97.75,
#   'ath_change_percentage': -61.95864,
#   'ath_date': '2021-11-21T12:39:57.508Z',
#   'atl': 1.89,
#   'atl_change_percentage': 1871.36614,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:21.926Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 0.17236,
#   'market_cap': 478588986,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 478588986,
#   'total_volume': 5748909,
#   'high_24h': 0.174449,
#   'low_24h': 0.171344,
#   'price_change_24h': -0.00180165587975617,
#   'price_change_percentage_24h': -1.03447,
#   'market_cap_change_24h': -5928331.57425499,
#   'market_cap_change_percentage_24h': -1.22355,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -96.71365,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 111.29213,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 3.365490687657574,
#    'currency': 'btc',
#    'percentage': 336.5490687657574},
#   'last_updated': '2023-08-10T15:56:59.539Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://assets.coingecko.com/coins/images/9519/large/paxgold.png?1687143101',
#   'current_price': 1921.6,
#   'market_cap': 477063854,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 477063854,
#   'total_volume': 9540653,
#   'high_24h': 1928.96,
#   'low_24h': 1915.82,
#   'price_change_24h': -3.743012427159101,
#   'price_change_percentage_24h': -0.19441,
#   'market_cap_change_24h': -574808.9192863107,
#   'market_cap_change_percentage_24h': -0.12034,
#   'circulating_supply': 248343.361,
#   'total_supply': 248343.361,
#   'max_supply': None,
#   'ath': 2241.37,
#   'ath_change_percentage': -14.33993,
#   'ath_date': '2021-05-17T19:02:29.657Z',
#   'atl': 1399.64,
#   'atl_change_percentage': 37.17502,
#   'atl_date': '2019-11-18T03:09:35.959Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:01.402Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://assets.coingecko.com/coins/images/10481/large/Tether_Gold.png?1668148656',
#   'current_price': 1932.83,
#   'market_cap': 476439804,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 476439804,
#   'total_volume': 5372368,
#   'high_24h': 1934.23,
#   'low_24h': 1913.82,
#   'price_change_24h': 15.18,
#   'price_change_percentage_24h': 0.7916,
#   'market_cap_change_24h': 4525627,
#   'market_cap_change_percentage_24h': 0.95899,
#   'circulating_supply': 246524.33,
#   'total_supply': 246524.33,
#   'max_supply': None,
#   'ath': 2169.74,
#   'ath_change_percentage': -11.06167,
#   'ath_date': '2023-03-15T20:36:21.941Z',
#   'atl': 1447.84,
#   'atl_change_percentage': 33.28333,
#   'atl_date': '2020-03-19T13:45:41.821Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:52.774Z'},
#  {'id': 'tokenize-xchange',
#   'symbol': 'tkx',
#   'name': 'Tokenize Xchange',
#   'image': 'https://assets.coingecko.com/coins/images/4984/large/TKX_-_Logo_-_RGB-15.png?1672912391',
#   'current_price': 5.72,
#   'market_cap': 457339409,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 571702847,
#   'total_volume': 7351201,
#   'high_24h': 5.76,
#   'low_24h': 5.71,
#   'price_change_24h': -0.02575314752509605,
#   'price_change_percentage_24h': -0.44828,
#   'market_cap_change_24h': -2002017.3647133708,
#   'market_cap_change_percentage_24h': -0.43585,
#   'circulating_supply': 79995999.94518414,
#   'total_supply': 100000000.0,
#   'max_supply': 100000000.0,
#   'ath': 22.3,
#   'ath_change_percentage': -74.33856,
#   'ath_date': '2022-10-31T10:23:59.455Z',
#   'atl': 0.111255,
#   'atl_change_percentage': 5042.73504,
#   'atl_date': '2019-04-28T00:00:00.000Z',
#   'roi': {'times': 18.687144983689382,
#    'currency': 'usd',
#    'percentage': 1868.7144983689384},
#   'last_updated': '2023-08-10T15:57:00.668Z'},
#  {'id': 'frax-ether',
#   'symbol': 'frxeth',
#   'name': 'Frax Ether',
#   'image': 'https://assets.coingecko.com/coins/images/28284/large/frxETH_icon.png?1679886981',
#   'current_price': 1849.08,
#   'market_cap': 456210471,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 456210471,
#   'total_volume': 5102177,
#   'high_24h': 1860.59,
#   'low_24h': 1841.7,
#   'price_change_24h': -0.41878004212912856,
#   'price_change_percentage_24h': -0.02264,
#   'market_cap_change_24h': 240764,
#   'market_cap_change_percentage_24h': 0.0528,
#   'circulating_supply': 246792.12441891,
#   'total_supply': 246792.12441891,
#   'max_supply': None,
#   'ath': 2134.61,
#   'ath_change_percentage': -13.31271,
#   'ath_date': '2023-04-16T19:24:52.171Z',
#   'atl': 1137.25,
#   'atl_change_percentage': 62.71187,
#   'atl_date': '2022-11-23T02:25:33.267Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:53.837Z'},
#  {'id': 'terra-luna',
#   'symbol': 'lunc',
#   'name': 'Terra Luna Classic',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/01_LunaClassic_color.png?1653547790',
#   'current_price': 7.764e-05,
#   'market_cap': 451767705,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 531449158,
#   'total_volume': 18681255,
#   'high_24h': 7.837e-05,
#   'low_24h': 7.7e-05,
#   'price_change_24h': -2.0210002383e-07,
#   'price_change_percentage_24h': -0.25962,
#   'market_cap_change_24h': -17759.25509607792,
#   'market_cap_change_percentage_24h': -0.00393,
#   'circulating_supply': 5813699446795.25,
#   'total_supply': 6839102581898.25,
#   'max_supply': None,
#   'ath': 119.18,
#   'ath_change_percentage': -99.99993,
#   'ath_date': '2022-04-05T12:24:58.854Z',
#   'atl': 9.99967e-07,
#   'atl_change_percentage': 7670.6138,
#   'atl_date': '2022-05-13T02:34:40.340Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:00.700Z'},
#  {'id': 'frax-share',
#   'symbol': 'fxs',
#   'name': 'Frax Share',
#   'image': 'https://assets.coingecko.com/coins/images/13423/large/Frax_Shares_icon.png?1679886947',
#   'current_price': 6.09,
#   'market_cap': 443211863,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 606708574,
#   'total_volume': 23502594,
#   'high_24h': 6.31,
#   'low_24h': 6.07,
#   'price_change_24h': -0.1886338008890487,
#   'price_change_percentage_24h': -3.00429,
#   'market_cap_change_24h': -14700093.841127336,
#   'market_cap_change_percentage_24h': -3.21024,
#   'circulating_supply': 72819368.5754524,
#   'total_supply': 99681752.7128909,
#   'max_supply': 99681752.7128909,
#   'ath': 42.8,
#   'ath_change_percentage': -85.76163,
#   'ath_date': '2022-01-12T15:22:27.465Z',
#   'atl': 1.5,
#   'atl_change_percentage': 305.41188,
#   'atl_date': '2021-06-25T16:50:51.447Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:53.940Z'},
#  {'id': 'bittorrent',
#   'symbol': 'btt',
#   'name': 'BitTorrent',
#   'image': 'https://assets.coingecko.com/coins/images/22457/large/btt_logo.png?1643857231',
#   'current_price': 4.64259e-07,
#   'market_cap': 441254827,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 459146846,
#   'total_volume': 16030759,
#   'high_24h': 4.66204e-07,
#   'low_24h': 4.63175e-07,
#   'price_change_24h': -2.17065729e-10,
#   'price_change_percentage_24h': -0.04673,
#   'market_cap_change_24h': -335852.58071780205,
#   'market_cap_change_percentage_24h': -0.07606,
#   'circulating_supply': 951421714286000.0,
#   'total_supply': 990000000000000.0,
#   'max_supply': 990000000000000.0,
#   'ath': 3.43e-06,
#   'ath_change_percentage': -86.4806,
#   'ath_date': '2022-01-21T04:00:31.909Z',
#   'atl': 4.54469e-07,
#   'atl_change_percentage': 2.07443,
#   'atl_date': '2023-08-07T17:05:11.236Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:54.319Z'},
#  {'id': 'casper-network',
#   'symbol': 'cspr',
#   'name': 'Casper Network',
#   'image': 'https://assets.coingecko.com/coins/images/15279/large/casper.PNG?1620341020',
#   'current_price': 0.03927779,
#   'market_cap': 440320242,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 467405685,
#   'total_volume': 4669307,
#   'high_24h': 0.0394934,
#   'low_24h': 0.03818704,
#   'price_change_24h': 0.00080101,
#   'price_change_percentage_24h': 2.0818,
#   'market_cap_change_24h': 9368883,
#   'market_cap_change_percentage_24h': 2.174,
#   'circulating_supply': 11234408264.0,
#   'total_supply': 11925471018.0,
#   'max_supply': None,
#   'ath': 1.33,
#   'ath_change_percentage': -97.07653,
#   'ath_date': '2021-05-12T00:00:00.000Z',
#   'atl': 0.02241297,
#   'atl_change_percentage': 72.88652,
#   'atl_date': '2022-06-18T20:14:44.694Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:02.990Z'},
#  {'id': 'gmx',
#   'symbol': 'gmx',
#   'name': 'GMX',
#   'image': 'https://assets.coingecko.com/coins/images/18323/large/arbit.png?1631532468',
#   'current_price': 49.13,
#   'market_cap': 439209692,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 650896363,
#   'total_volume': 13599995,
#   'high_24h': 50.36,
#   'low_24h': 49.07,
#   'price_change_24h': -1.1698448419861975,
#   'price_change_percentage_24h': -2.32567,
#   'market_cap_change_24h': -10807922.564211011,
#   'market_cap_change_percentage_24h': -2.40167,
#   'circulating_supply': 8940791.12080234,
#   'total_supply': 8940818.45604026,
#   'max_supply': 13250000.0,
#   'ath': 91.07,
#   'ath_change_percentage': -45.97527,
#   'ath_date': '2023-04-18T10:00:25.680Z',
#   'atl': 11.53,
#   'atl_change_percentage': 326.57975,
#   'atl_date': '2022-06-15T09:30:22.146Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:55.679Z'},
#  {'id': 'mina-protocol',
#   'symbol': 'mina',
#   'name': 'Mina Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/15628/large/JM4_vQ34_400x400.png?1621394004',
#   'current_price': 0.461352,
#   'market_cap': 437750935,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 490070517,
#   'total_volume': 11171122,
#   'high_24h': 0.464994,
#   'low_24h': 0.450985,
#   'price_change_24h': 0.00410093,
#   'price_change_percentage_24h': 0.89687,
#   'market_cap_change_24h': 4661876,
#   'market_cap_change_percentage_24h': 1.07642,
#   'circulating_supply': 948522743.840039,
#   'total_supply': 1061889292.84004,
#   'max_supply': None,
#   'ath': 9.09,
#   'ath_change_percentage': -94.89791,
#   'ath_date': '2021-06-01T01:42:37.064Z',
#   'atl': 0.380741,
#   'atl_change_percentage': 21.81449,
#   'atl_date': '2023-06-10T06:00:03.859Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:02.060Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://assets.coingecko.com/coins/images/26375/large/sui_asset.jpeg?1683114182',
#   'current_price': 0.60022,
#   'market_cap': 434548446,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 6009003951,
#   'total_volume': 64496559,
#   'high_24h': 0.603178,
#   'low_24h': 0.588257,
#   'price_change_24h': -0.002958005986398504,
#   'price_change_percentage_24h': -0.4904,
#   'market_cap_change_24h': -979872.0466790199,
#   'market_cap_change_percentage_24h': -0.22498,
#   'circulating_supply': 723162190.461538,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.16,
#   'ath_change_percentage': -72.20285,
#   'ath_date': '2023-05-03T12:00:26.430Z',
#   'atl': 0.557963,
#   'atl_change_percentage': 7.73441,
#   'atl_date': '2023-06-10T06:00:47.648Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:01.031Z'},
#  {'id': 'huobi-token',
#   'symbol': 'ht',
#   'name': 'Huobi',
#   'image': 'https://assets.coingecko.com/coins/images/2822/large/huobi-token-logo.png?1547036992',
#   'current_price': 2.59,
#   'market_cap': 412638403,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 520437818,
#   'total_volume': 14419268,
#   'high_24h': 2.62,
#   'low_24h': 2.58,
#   'price_change_24h': -0.015206639506325729,
#   'price_change_percentage_24h': -0.58411,
#   'market_cap_change_24h': -2563493.427924454,
#   'market_cap_change_percentage_24h': -0.61741,
#   'circulating_supply': 159406077.0,
#   'total_supply': 201050000.0,
#   'max_supply': 201050000.0,
#   'ath': 39.66,
#   'ath_change_percentage': -93.48354,
#   'ath_date': '2021-05-12T14:42:21.586Z',
#   'atl': 0.3138,
#   'atl_change_percentage': 723.60653,
#   'atl_date': '2023-03-10T05:05:00+08:00',
#   'roi': {'times': 1.614311255486086,
#    'currency': 'usd',
#    'percentage': 161.43112554860858},
#   'last_updated': '2023-08-10T15:56:55.117Z'},
#  {'id': 'compound-governance-token',
#   'symbol': 'comp',
#   'name': 'Compound',
#   'image': 'https://assets.coingecko.com/coins/images/10775/large/COMP.png?1592625425',
#   'current_price': 55.88,
#   'market_cap': 382617535,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 558069937,
#   'total_volume': 55445072,
#   'high_24h': 57.03,
#   'low_24h': 54.97,
#   'price_change_24h': -0.01356669823372414,
#   'price_change_percentage_24h': -0.02427,
#   'market_cap_change_24h': -336808.3250473738,
#   'market_cap_change_percentage_24h': -0.08795,
#   'circulating_supply': 6856085.76329154,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 910.54,
#   'ath_change_percentage': -93.85343,
#   'ath_date': '2021-05-12T02:29:08.794Z',
#   'atl': 25.74,
#   'atl_change_percentage': 117.42993,
#   'atl_date': '2023-06-10T16:15:05.289Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:56:56.460Z'},
#  {'id': 'trust-wallet-token',
#   'symbol': 'twt',
#   'name': 'Trust Wallet',
#   'image': 'https://assets.coingecko.com/coins/images/11085/large/Trust.png?1588062702',
#   'current_price': 0.910972,
#   'market_cap': 379625224,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 911137201,
#   'total_volume': 4318631,
#   'high_24h': 0.919373,
#   'low_24h': 0.90366,
#   'price_change_24h': -0.000759917098251628,
#   'price_change_percentage_24h': -0.08335,
#   'market_cap_change_24h': 433799,
#   'market_cap_change_percentage_24h': 0.1144,
#   'circulating_supply': 416649900.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 2.72,
#   'ath_change_percentage': -66.56225,
#   'ath_date': '2022-12-11T23:25:46.205Z',
#   'atl': 0.00277641,
#   'atl_change_percentage': 32669.30275,
#   'atl_date': '2020-06-09T09:15:06.983Z',
#   'roi': None,
#   'last_updated': '2023-08-10T15:57:02.668Z'}]

# %% [markdown]
# Estan ordenadas por Market Cap asi que nos quedariamos con las primeras 10 monedas.

# %%
coinsTopIds = []
for i in range(10):
    coinsTopIds.append(coinsMarket[i]['id'])
coinsTopIds
# Out:
# ['bitcoin',
#  'ethereum',
#  'tether',
#  'binancecoin',
#  'ripple',
#  'usd-coin',
#  'staked-ether',
#  'dogecoin',
#  'cardano',
#  'solana']

# %%
# Testing coins ids.
cg.get_price(ids=coinsTopIds, vs_currencies=['usd'])
# Out:
# {'binancecoin': {'usd': 242.12},
#  'bitcoin': {'usd': 29467},
#  'cardano': {'usd': 0.298168},
#  'dogecoin': {'usd': 0.075839},
#  'ethereum': {'usd': 1851.61},
#  'ripple': {'usd': 0.630705},
#  'solana': {'usd': 24.49},
#  'staked-ether': {'usd': 1850.47},
#  'tether': {'usd': 0.999073},
#  'usd-coin': {'usd': 1.0}}

# %% [markdown]
# ## Get Historical Data
#
# There are 3 different endpoints to get historical data of a coin:
#
# | Endpoint | Description |
# | - | - |
# | /coins/{id}/history | To get the price & market data of a coin on a specific day in the past (00:00 UTC) |
# | /coins/{id}/market_chart | To get list of historical price & market data of a coin for X days before today. |
# | /coins/{id}/market_chart/range | To get list of historical price & market data of a coin for a date range, between 'from' and 'to'. |

# %% [markdown]
# ### Endpoint market Chart
# Estos endpoint tienen una ventaja significativa que es poder hacer la consulta para un rango de fechas. Pero la gran desventaja que solo devuelve tres valores. 'prices', 'market_caps', 'total_volumes'.

# %%
import datetime
import time

idCoin = "bitcoin"

initialDate = datetime.date(2020, 7, 1)
endDate = datetime.date(2023, 7, 1)
# To unix
initialDate = time.mktime(initialDate.timetuple())
endDate = time.mktime(endDate.timetuple())


respDict = cg.get_coin_market_chart_range_by_id(id='bitcoin', vs_currency='usd',
                                     from_timestamp=initialDate, to_timestamp=endDate)

# %%
pd.DataFrame(respDict).columns
# Out:
# Index(['prices', 'market_caps', 'total_volumes'], dtype='object')

# %%
pd.DataFrame(respDict)
# Out:
#                                    prices
# 0      [1593648000000, 9230.672998590804]  \
# 1      [1593734400000, 9094.318072166905]
# 2        [1593820800000, 9071.3850427828]
# 3      [1593907200000, 9132.908369533492]
# 4      [1593993600000, 9087.407312582163]
# ...                                   ...
# 1090   [1687824000000, 30285.50506407074]
# 1091   [1687910400000, 30693.54635606798]
# 1092  [1687996800000, 30083.477245263824]
# 1093  [1688083200000, 30466.610456893526]
# 1094  [1688169600000, 30480.781481944465]
#
#                               market_caps                        total_volumes
# 0     [1593648000000, 170031996602.76715]  [1593648000000, 20005031554.019035]
# 1     [1593734400000, 167604994105.34857]  [1593734400000, 19379463385.296654]
# 2     [1593820800000, 167116284671.21997]   [1593820800000, 17420495829.39433]
# 3     [1593907200000, 168258822207.29507]  [1593907200000, 16643732672.692139]
# 4     [1593993600000, 167429736492.90482]  [1593993600000, 17324463886.377956]
# ...                                   ...                                  ...
# 1090   [1687824000000, 587134340343.6245]  [1687824000000, 16032184116.631308]
# 1091   [1687910400000, 595427193050.2291]  [1687910400000, 14411853963.110468]
# 1092   [1687996800000, 584187696961.3756]   [1687996800000, 8489428028.028098]
# 1093   [1688083200000, 591688337868.8445]  [1688083200000, 12545425127.446297]
# 1094   [1688169600000, 591722375245.7673]  [1688169600000, 21422361050.823097]
#
# [1095 rows x 3 columns]

# %% [markdown]
# ### Endpoint Hisotry
# La ventaja que tiene este endpoint es que ademas de devolvernos 'prices', 'market_caps' y 'total_volumes' tambien devuelve otras variables como son 'community_data', 'developer_data' y 'public_interest_stats'.
#
# La gran desventaja que presenta es que no hay una forma de consultar un rango, habria que hacer una consulta por cada moneda para cada dia que se quiera consultar.
#
# Si tomaramos un rango de 2 años, para 10 monedas serian unas `2 * 365 * 10 = 7300` consultas.
#
# Teniendo en cuenta que la API Acepta 10-30 request por minuto, precisariamos entre `7300/30 = 244 minutos = 4 hs`  `7300/10 = 730 minutos = 12 hs`

# %%
cg.get_coin_history_by_id(coinsTopIds[1], date="10-01-2021", localization=False)
# Out:
# {'id': 'ethereum',
#  'symbol': 'eth',
#  'name': 'Ethereum',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/279/thumb/ethereum.png?1595348880',
#   'small': 'https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880'},
#  'market_data': {'current_price': {'aed': 4712.383980911869,
#    'ars': 109192.92907641415,
#    'aud': 1653.3244597990392,
#    'bch': 2.209034328335233,
#    'bdt': 108967.92781633575,
#    'bhd': 483.4921360170462,
#    'bmd': 1282.979575527323,
#    'bnb': 29.161517463426947,
#    'brl': 6947.924572085209,
#    'btc': 0.03183786765048036,
#    'cad': 1627.9856131823747,
#    'chf': 1136.1489780060986,
#    'clp': 913164.2872626679,
#    'cny': 8307.805943369609,
#    'czk': 27468.785158976305,
#    'dkk': 7807.738994216325,
#    'dot': 130.8308108900062,
#    'eos': 354.04062524948944,
#    'eth': 1.0,
#    'eur': 1049.4721608630475,
#    'gbp': 945.7676387935976,
#    'hkd': 9951.302779620124,
#    'huf': 377401.2719371157,
#    'idr': 18135365.34293014,
#    'ils': 4083.6341803331716,
#    'inr': 94142.98848487397,
#    'jpy': 133363.16091691406,
#    'krw': 1402309.50584712,
#    'kwd': 389.2906436635278,
#    'lkr': 241708.20599827016,
#    'ltc': 7.213546698260287,
#    'mmk': 1706742.6846483063,
#    'mxn': 25671.587369577628,
#    'myr': 5173.61513831394,
#    'ngn': 508489.93587102636,
#    'nok': 10804.86909121844,
#    'nzd': 1770.9711209157417,
#    'php': 61685.65799135362,
#    'pkr': 206030.58009144154,
#    'pln': 4736.439847952976,
#    'rub': 95047.74568153592,
#    'sar': 4813.444282076141,
#    'sek': 10576.999088809045,
#    'sgd': 1701.1282787831863,
#    'thb': 38664.00720094674,
#    'try': 9463.51394500463,
#    'twd': 35946.52174712466,
#    'uah': 36348.884669683175,
#    'usd': 1282.979575527323,
#    'vef': 128.46474489755073,
#    'vnd': 29657030.632567175,
#    'xag': 50.46138287689525,
#    'xau': 0.6938225246494206,
#    'xdr': 888.6519540502746,
#    'xlm': 4107.603025050182,
#    'xrp': 3924.670117956281,
#    'yfi': 0.03527822249794751,
#    'zar': 19634.00737020572,
#    'bits': 31837.867650480362,
#    'link': 72.56962322370389,
#    'sats': 3183786.7650480364},
#   'market_cap': {'aed': 541392456969.14307,
#    'ars': 12544866546485.934,
#    'aud': 189945767383.02652,
#    'bch': 260090201.14086488,
#    'bdt': 12519016788590.924,
#    'bhd': 55547042962.504456,
#    'bmd': 147397891905.5662,
#    'bnb': 3338320387.933581,
#    'brl': 798227387698.9174,
#    'btc': 3642416.626551436,
#    'cad': 187034659017.89166,
#    'chf': 130528940166.43356,
#    'clp': 104910860214313.6,
#    'cny': 954460309245.3014,
#    'czk': 3155810975381.9556,
#    'dkk': 897009032917.2697,
#    'dot': 15079389455.50144,
#    'eos': 40552584278.41605,
#    'eth': 114186598.624,
#    'eur': 120570885987.18521,
#    'gbp': 108656566986.56667,
#    'hkd': 1143277008776.3337,
#    'huf': 43358563882941.29,
#    'idr': 2083520791347343.2,
#    'ils': 469157172082.9824,
#    'inr': 10815821471403.398,
#    'jpy': 15321716067799.76,
#    'krw': 161107369831702.66,
#    'kwd': 44724500147.23009,
#    'lkr': 27769171622064.184,
#    'ltc': 832839620.1011189,
#    'mmk': 196082836033463.47,
#    'mxn': 2949336008400.637,
#    'myr': 594381999109.1957,
#    'ngn': 58418969430421.54,
#    'nok': 1241340826261.106,
#    'nzd': 203461859274.9834,
#    'php': 7086890642819.6,
#    'pkr': 23670270168624.875,
#    'pln': 544156167442.37506,
#    'rub': 10919766464775.193,
#    'sar': 553002988914.5458,
#    'sek': 1215161486679.759,
#    'sgd': 195437812835.4281,
#    'thb': 4441998347244.77,
#    'try': 1087236330273.835,
#    'twd': 4129794135410.155,
#    'uah': 4176020472678.013,
#    'usd': 147397891905.5662,
#    'vef': 14758950916.504332,
#    'vnd': 3407212303923464.5,
#    'xag': 5797365445.694568,
#    'xau': 79711305.96361104,
#    'xdr': 102094707634.71445,
#    'xlm': 466702222950.6608,
#    'xrp': 445607050184.9789,
#    'yfi': 4038092.053473877,
#    'zar': 2255695531892.7734,
#    'bits': 3642416626551.4355,
#    'link': 8246649388.698351,
#    'sats': 364241662655143.56},
#   'total_volume': {'aed': 128008156747.00934,
#    'ars': 2966138930421.787,
#    'aud': 44911241838.715096,
#    'bch': 60006657.71432803,
#    'bdt': 2960026950437.759,
#    'bhd': 13133678703.584806,
#    'bmd': 34851118090.66404,
#    'bnb': 792149390.5334662,
#    'brl': 188734835975.2678,
#    'btc': 864850.3112652968,
#    'cad': 44222932256.42449,
#    'chf': 30862581880.777996,
#    'clp': 24805380396245.086,
#    'cny': 225674930084.28543,
#    'czk': 746167665988.8304,
#    'dkk': 212091009786.0873,
#    'dot': 3553914752.18994,
#    'eos': 9617231540.409443,
#    'eth': 27154032.015042856,
#    'eur': 28508075193.690807,
#    'gbp': 25691024467.304317,
#    'hkd': 270319212358.42645,
#    'huf': 10251804897549.69,
#    'idr': 492632752102867.9,
#    'ils': 110928669304.317,
#    'inr': 2557319283703.9785,
#    'jpy': 3622704023288.343,
#    'krw': 38092620584276.72,
#    'kwd': 10574770208.895885,
#    'lkr': 6565810860446.442,
#    'ltc': 195950249.42642587,
#    'mmk': 46362305361414.03,
#    'mxn': 697348219767.4281,
#    'myr': 140537133700.60303,
#    'ngn': 13812724022260.104,
#    'nok': 293505661224.1449,
#    'nzd': 48107019665.39276,
#    'php': 1675641757799.125,
#    'pkr': 5596656575069.481,
#    'pln': 128661615211.20848,
#    'rub': 2581896292181.5166,
#    'sar': 130753379319.01051,
#    'sek': 287315754140.06244,
#    'sgd': 46209794498.77322,
#    'thb': 1050276954147.6484,
#    'try': 257068817260.3558,
#    'twd': 976458626664.2285,
#    'uah': 987388494915.3484,
#    'usd': 34851118090.66404,
#    'vef': 3489642454.418187,
#    'vnd': 805609611025353.2,
#    'xag': 1370743266.0711408,
#    'xau': 18847136.152250197,
#    'xdr': 24139522392.1442,
#    'xlm': 111579763876.40788,
#    'xrp': 106610537187.684,
#    'yfi': 958304.8099572072,
#    'zar': 533342168888.98175,
#    'bits': 864850311265.2968,
#    'link': 1971296002.6856158,
#    'sats': 86485031126529.67}},
#  'community_data': {'facebook_likes': None,
#   'twitter_followers': None,
#   'reddit_average_posts_48h': 6.167,
#   'reddit_average_comments_48h': 131.25,
#   'reddit_subscribers': 526191,
#   'reddit_accounts_active_48h': '2526.69230769231'},
#  'developer_data': {'forks': 10209,
#   'stars': 27668,
#   'subscribers': 2023,
#   'total_issues': 5267,
#   'closed_issues': 5084,
#   'pull_requests_merged': 3426,
#   'pull_request_contributors': 496,
#   'code_additions_deletions_4_weeks': {'additions': 9717, 'deletions': -4142},
#   'commit_count_4_weeks': 48},
#  'public_interest_stats': {'alexa_rank': None, 'bing_matches': None}}

# %% [markdown]
# ---

# %% [markdown]
# Preparacion de la consulta, preprocesamiento de los datos y guardado en JSON para hacerlo de forma iterativa durante varias horas.

# %%
dateRequest = "08-01-2021"
r = cg.get_coin_history_by_id('solana', date=dateRequest, localization=False)

# %% [markdown]
# Preprocesar la data antes de guardarla.

# %%
# Agregarle la fecha al dato levantado
r['date'] = dateRequest

# Eliminar images que no la vamos a precisar
del(r['image'])

# Me quedo con el valore en dolares de estas tres variables importantes y borro el resto de la data en 'market_data'
r['current_price'] = r['market_data']['current_price']['usd']
r['market_cap'] = r['market_data']['market_cap']['usd']
r['total_volume'] = r['market_data']['total_volume']['usd']
del(r['market_data'])

# Sacar de community_data para llevarlo a la raiz.
r.update(r['community_data'])
del(r['community_data'])

# Sacar de developer_data para llevarlo a la raiz.
r.update(r['developer_data'])
del(r['developer_data'])

# Sacar de public_interest_stats para llevarlo a la raiz.
r.update(r['public_interest_stats'])
del(r['public_interest_stats'])

# Sacar de code_additions_deletions_4_weeks para llevarlo a la raiz.
r.update(r['code_additions_deletions_4_weeks'])
del(r['code_additions_deletions_4_weeks'])

r
# Out:
# {'id': 'solana',
#  'symbol': 'sol',
#  'name': 'Solana',
#  'date': '08-01-2021',
#  'current_price': 2.3674092848829695,
#  'market_cap': 617487734.823374,
#  'total_volume': 219251174.2197483,
#  'facebook_likes': None,
#  'twitter_followers': 105832,
#  'reddit_average_posts_48h': 0.545,
#  'reddit_average_comments_48h': 6.364,
#  'reddit_subscribers': 2875,
#  'reddit_accounts_active_48h': '62.5833333333333',
#  'forks': 257,
#  'stars': 1115,
#  'subscribers': 83,
#  'total_issues': 2565,
#  'closed_issues': 2134,
#  'pull_requests_merged': 10433,
#  'pull_request_contributors': 82,
#  'commit_count_4_weeks': 213,
#  'alexa_rank': None,
#  'bing_matches': None,
#  'additions': 20725,
#  'deletions': -18749}

# %%
import json

with open("datasets/raw_coins_data.json", "a") as outfile:
    json.dump(r, outfile)
    outfile.write("\n")

# %% [markdown]
# # Get Automatic Data

# %%
import json
import pandas as pd
from pycoingecko import CoinGeckoAPI

# Creemos la funcionalidad de Coin Gecko.
cg = CoinGeckoAPI()

def new_data_request(coin_id, dateRequest):
    r = cg.get_coin_history_by_id(coin_id, date=dateRequest, localization=False)

    # Agregarle la fecha al dato levantado
    r['date'] = dateRequest

    # Eliminar images que no la vamos a precisar
    del(r['image'])

    # Me quedo con el valore en dolares de estas tres variables importantes y borro el resto de la data en 'market_data'
    r['current_price'] = r['market_data']['current_price']['usd']
    r['market_cap'] = r['market_data']['market_cap']['usd']
    r['total_volume'] = r['market_data']['total_volume']['usd']
    del(r['market_data'])

    # Sacar de community_data para llevarlo a la raiz.
    r.update(r['community_data'])
    del(r['community_data'])

    # Sacar de developer_data para llevarlo a la raiz.
    r.update(r['developer_data'])
    del(r['developer_data'])

    # Sacar de public_interest_stats para llevarlo a la raiz.
    r.update(r['public_interest_stats'])
    del(r['public_interest_stats'])

    # Sacar de code_additions_deletions_4_weeks para llevarlo a la raiz.
    r.update(r['code_additions_deletions_4_weeks'])
    del(r['code_additions_deletions_4_weeks'])

    # Guardo el nuevo registro en el json.
    with open("datasets/raw_coins_data.json", "a") as outfile:
        json.dump(r, outfile)
        outfile.write("\n")

# %%
# importing the required lib
from datetime import date
from dateutil.rrule import rrule, DAILY
import time

# initializing the start and end date
start_date = date(2021, 1, 4)
end_date = date(2021, 1, 5)

# iterating over the dates
# for d in rrule(DAILY, dtstart=start_date, until=end_date):
#     d = d.strftime("%d-%m-%Y")
#     new_data_request('bitcoin', d)
#     time.sleep(5)

# coinNames = ['bitcoin', 'ethereum', 'tether', 'binancecoin', 'ripple', 'usd-coin', 'staked-ether', 'dogecoin', 'cardano', 'solana']
coinNames = ['ethereum', 'tether', 'binancecoin', 'ripple', 'usd-coin', 'staked-ether', 'dogecoin', 'cardano', 'solana']

# iterating over the dates
for d in rrule(DAILY, dtstart=start_date, until=end_date):
    d = d.strftime("%d-%m-%Y")
    for coin in coinNames:
        new_data_request(coin, d)
        print(d, coin)
        time.sleep(5)
# Out:
# 04-01-2021 ethereum
# 04-01-2021 tether
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 25
#      23 new_data_request(coin, d)
#      24 print(d, coin)
# ---> 25 time.sleep(5)
#
# KeyboardInterrupt:
